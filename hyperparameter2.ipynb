# %% [markdown]
# ### Hyperparameter Optimization
#
# 1. GridsearchCV
# 2. RandomizedSearch
# 3. Optuna
# 4. HyperOpt

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import f1_score, mean_squared_error


from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

from sklearn import datasets

# %%
data = datasets.load_diabetes(as_frame=True)['data']
y = datasets.load_diabetes()['target']

# %%
reg = RandomForestRegressor(random_state= 42, n_jobs= -1)

parameters = {
    
    'n_estimators': list(range(10,60,10)),
    'max_depth': list(range(2,12,2)),
    'criterion': ['squared_error','absolute_error'],
    'max_features': ['sqrt', 'log2']
}

model = GridSearchCV(estimator=reg, param_grid=parameters,
                     n_jobs= 1, cv=5, verbose=10, return_train_score= True,
                     scoring= 'neg_root_mean_squared_error')

model.fit(X = data, y = y)

# %%
model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'n_estimators': 50}

# %%
model.best_score_
# Out:
# -56.41173460834938

# %%
model.best_estimator_
# Out:
# RandomForestRegressor(max_depth=4, max_features='sqrt', n_estimators=50,
#                       n_jobs=-1, random_state=42)

# %%
model.best_index_
# Out:
# 14

# %% [markdown]
# ### Classification

# %%
data = datasets.load_breast_cancer(as_frame=True)['data']
y = datasets.load_breast_cancer()['target']


classifier = RandomForestClassifier(random_state= 2, n_jobs= 1)


param_grid = {
    'n_estimators': list(range(10,60,10)),
    'max_depth': list(range(2,12, 2)),
    'criterion' : ['gini', 'entropy']
}

model_classifier = GridSearchCV(estimator= classifier, param_grid=param_grid,
                                scoring='f1',n_jobs=1, verbose = 10,
                                cv = 5, return_train_score=True
                                )
model_classifier.fit(data, y)

# %% [markdown]
# ### Randomized Search

# %%
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

# loading the dataset
X = datasets.load_breast_cancer(as_frame=True)['data']
y = datasets.load_breast_cancer()['target']

# setting up the cross validation
s_fold = StratifiedKFold(n_splits= 10, shuffle= True, random_state= 30)

# setting up the model
xgb_classifier = XGBClassifier(random_state = 23, n_jobs = 1)


# setting up the search

parameters = {
    'n_estimators': list(range(10,2000,10)),
    'learning_rate': [x/100 for x in range(10, 95, 5)],
    'max_depth' : list(range(2,50,2)),
    'max_delta_step': list(range(0,50,1)),
    'subsample': [0,1]
}

# training and tuning the model

model = RandomizedSearchCV(estimator= xgb_classifier, param_distributions= parameters,
                           n_iter=40, scoring='f1', n_jobs=1, cv = s_fold.split(X,y),
                           verbose= 3, random_state= 32, return_train_score= True)

model.fit(X, y)

best_model = model.best_estimator_
best_score = model.best_score_
best_parameters = model.best_params_

for i in [best_score,best_parameters]:
    print(i)
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [CV 1/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 2/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 3/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 4/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 6/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.960) total time=   0.4s
# [CV 7/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.943) total time=   0.3s
# [CV 8/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 9/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 10/10] END learning_rate=0.75, max_delta_step=9, max_depth=40, n_estimators=470, subsample=1;, score=(train=1.000, test=0.957) total time=   0.3s
# [CV 1/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.986) total time=   1.6s
# [CV 2/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 3/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.972) total time=   1.1s
# [CV 4/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.986) total time=   0.6s
# [CV 5/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.986) total time=   0.8s
# [CV 6/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.946) total time=   0.8s
# [CV 7/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.943) total time=   0.8s
# [CV 8/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=1.000) total time=   0.8s
# [CV 9/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.986) total time=   0.6s
# [CV 10/10] END learning_rate=0.55, max_delta_step=27, max_depth=42, n_estimators=1300, subsample=1;, score=(train=1.000, test=0.986) total time=   0.8s
# [CV 1/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.971) total time=   0.0s
# [CV 2/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.971) total time=   0.0s
# [CV 3/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.946) total time=   0.0s
# [CV 4/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 5/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 6/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.946) total time=   0.0s
# [CV 7/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.957) total time=   0.0s
# [CV 8/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 9/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 10/10] END learning_rate=0.8, max_delta_step=27, max_depth=14, n_estimators=10, subsample=1;, score=(train=1.000, test=0.958) total time=   0.0s
# [CV 1/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.772, test=0.761) total time=   1.0s
# [CV 2/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 3/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 4/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 5/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 6/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 7/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 8/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 9/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 10/10] END learning_rate=0.6, max_delta_step=1, max_depth=42, n_estimators=720, subsample=0;, score=(train=0.771, test=0.769) total time=   0.3s
# [CV 1/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.772, test=0.761) total time=   0.0s
# [CV 2/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.772, test=0.761) total time=   0.0s
# [CV 3/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 4/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 5/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 6/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 7/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 8/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 9/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 10/10] END learning_rate=0.25, max_delta_step=48, max_depth=22, n_estimators=90, subsample=0;, score=(train=0.771, test=0.769) total time=   0.0s
# [CV 1/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.772, test=0.761) total time=   0.4s
# [CV 2/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.772, test=0.761) total time=   0.4s
# [CV 3/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 4/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 5/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 6/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 7/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 8/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 9/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 10/10] END learning_rate=0.2, max_delta_step=39, max_depth=18, n_estimators=1120, subsample=0;, score=(train=0.771, test=0.769) total time=   1.2s
# [CV 1/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.772, test=0.761) total time=   2.6s
# [CV 2/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.772, test=0.761) total time=   1.8s
# [CV 3/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.3s
# [CV 4/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.5s
# [CV 5/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.8s
# [CV 6/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   2.2s
# [CV 7/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.3s
# [CV 8/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.4s
# [CV 9/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.3s
# [CV 10/10] END learning_rate=0.35, max_delta_step=10, max_depth=4, n_estimators=1980, subsample=0;, score=(train=0.771, test=0.769) total time=   1.6s
# [CV 1/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=0.972) total time=   1.2s
# [CV 2/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=1.000) total time=   1.5s
# [CV 3/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=1.000) total time=   1.4s
# [CV 4/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=0.973) total time=   1.4s
# [CV 5/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=1.000) total time=   1.2s
# [CV 6/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=0.959) total time=   1.7s
# [CV 7/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=0.943) total time=   1.2s
# [CV 8/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=1.000) total time=   1.6s
# [CV 9/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=0.986) total time=   1.6s
# [CV 10/10] END learning_rate=0.1, max_delta_step=40, max_depth=12, n_estimators=1670, subsample=1;, score=(train=1.000, test=0.986) total time=   1.4s
# [CV 1/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.772, test=0.761) total time=   1.8s
# [CV 2/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.772, test=0.761) total time=   1.7s
# [CV 3/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   1.6s
# [CV 4/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   1.1s
# [CV 5/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 6/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 7/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   1.2s
# [CV 8/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   1.2s
# [CV 9/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.774) total time=   1.2s
# [CV 10/10] END learning_rate=0.25, max_delta_step=3, max_depth=26, n_estimators=1950, subsample=0;, score=(train=0.771, test=0.769) total time=   1.8s
# [CV 1/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 2/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 3/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 4/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 5/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 6/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 7/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.943) total time=   0.1s
# [CV 8/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 9/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.972) total time=   0.4s
# [CV 10/10] END learning_rate=0.65, max_delta_step=21, max_depth=26, n_estimators=240, subsample=1;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 1/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.772, test=0.761) total time=   0.6s
# [CV 2/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.772, test=0.761) total time=   0.6s
# [CV 3/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 4/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 5/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 6/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 7/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 8/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 9/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.774) total time=   1.3s
# [CV 10/10] END learning_rate=0.85, max_delta_step=37, max_depth=38, n_estimators=1380, subsample=0;, score=(train=0.771, test=0.769) total time=   1.3s
# [CV 1/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=0.972) total time=   1.7s
# [CV 2/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=1.000) total time=   1.8s
# [CV 3/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=1.000) total time=   1.1s
# [CV 4/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=0.973) total time=   1.7s
# [CV 5/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=1.000) total time=   1.7s
# [CV 6/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=0.959) total time=   1.2s
# [CV 7/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=0.943) total time=   0.9s
# [CV 8/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=1.000) total time=   0.9s
# [CV 9/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 10/10] END learning_rate=0.1, max_delta_step=38, max_depth=22, n_estimators=1190, subsample=1;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 1/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.8s
# [CV 2/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 3/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.986) total time=   1.1s
# [CV 4/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.973) total time=   1.7s
# [CV 5/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.986) total time=   1.2s
# [CV 6/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.960) total time=   1.7s
# [CV 7/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.943) total time=   1.1s
# [CV 8/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 9/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.972) total time=   0.7s
# [CV 10/10] END learning_rate=0.75, max_delta_step=14, max_depth=10, n_estimators=1660, subsample=1;, score=(train=1.000, test=0.957) total time=   0.9s
# [CV 1/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 2/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   0.6s
# [CV 3/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.960) total time=   0.9s
# [CV 4/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.973) total time=   0.8s
# [CV 5/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   0.6s
# [CV 6/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.960) total time=   0.7s
# [CV 7/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.957) total time=   0.5s
# [CV 8/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   0.5s
# [CV 9/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.972) total time=   0.6s
# [CV 10/10] END learning_rate=0.45, max_delta_step=45, max_depth=44, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.971) total time=   1.0s
# [CV 1/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.772, test=0.761) total time=   0.4s
# [CV 2/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.772, test=0.761) total time=   0.8s
# [CV 3/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   1.0s
# [CV 4/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 5/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 6/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 7/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 8/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 9/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 10/10] END learning_rate=0.4, max_delta_step=38, max_depth=44, n_estimators=830, subsample=0;, score=(train=0.771, test=0.769) total time=   0.5s
# [CV 1/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=0.972) total time=   2.8s
# [CV 2/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=1.000) total time=   2.4s
# [CV 3/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=1.000) total time=   1.7s
# [CV 4/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=0.973) total time=   1.8s
# [CV 5/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=1.000) total time=   1.4s
# [CV 6/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=0.959) total time=   1.4s
# [CV 7/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=0.943) total time=   1.3s
# [CV 8/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=1.000) total time=   1.6s
# [CV 9/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=0.986) total time=   1.7s
# [CV 10/10] END learning_rate=0.1, max_delta_step=45, max_depth=22, n_estimators=1830, subsample=1;, score=(train=1.000, test=0.986) total time=   2.1s
# [CV 1/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.772, test=0.761) total time=   0.2s
# [CV 2/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.772, test=0.761) total time=   0.2s
# [CV 3/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 4/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 5/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.2s
# [CV 6/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 7/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.2s
# [CV 8/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 9/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 10/10] END learning_rate=0.85, max_delta_step=8, max_depth=34, n_estimators=350, subsample=0;, score=(train=0.771, test=0.769) total time=   0.2s
# [CV 1/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 2/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 3/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 4/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 5/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=1.000) total time=   0.2s
# [CV 6/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 7/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.943) total time=   0.1s
# [CV 8/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 9/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 10/10] END learning_rate=0.25, max_delta_step=10, max_depth=18, n_estimators=140, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 1/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=1.000, test=0.971) total time=   0.0s
# [CV 2/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.998, test=0.986) total time=   0.0s
# [CV 3/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.997, test=0.946) total time=   0.1s
# [CV 4/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.998, test=0.973) total time=   0.0s
# [CV 5/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.998, test=0.972) total time=   0.5s
# [CV 6/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.997, test=0.960) total time=   0.0s
# [CV 7/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.997, test=0.957) total time=   0.1s
# [CV 8/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=0.998, test=0.973) total time=   0.0s
# [CV 9/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=1.000, test=0.958) total time=   0.1s
# [CV 10/10] END learning_rate=0.45, max_delta_step=32, max_depth=18, n_estimators=10, subsample=1;, score=(train=1.000, test=0.972) total time=   0.0s
# [CV 1/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 2/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 3/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.960) total time=   0.6s
# [CV 4/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 6/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.960) total time=   0.2s
# [CV 7/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.957) total time=   0.2s
# [CV 8/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 9/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 10/10] END learning_rate=0.45, max_delta_step=48, max_depth=46, n_estimators=560, subsample=1;, score=(train=1.000, test=0.971) total time=   0.3s
# [CV 1/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 2/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.772, test=0.761) total time=   0.6s
# [CV 3/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 4/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 5/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 6/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 7/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 8/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 9/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 10/10] END learning_rate=0.85, max_delta_step=6, max_depth=28, n_estimators=1510, subsample=0;, score=(train=0.771, test=0.769) total time=   0.6s
# [CV 1/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.971) total time=   0.0s
# [CV 2/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 3/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 4/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.973) total time=   0.1s
# [CV 5/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 6/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.960) total time=   0.1s
# [CV 7/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.957) total time=   0.0s
# [CV 8/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 9/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 10/10] END learning_rate=0.7, max_delta_step=45, max_depth=40, n_estimators=50, subsample=1;, score=(train=1.000, test=0.943) total time=   0.0s
# [CV 1/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 2/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 3/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 4/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 5/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 6/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 7/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 8/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 9/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 10/10] END learning_rate=0.45, max_delta_step=9, max_depth=42, n_estimators=1050, subsample=0;, score=(train=0.771, test=0.769) total time=   0.5s
# [CV 1/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.772, test=0.761) total time=   0.3s
# [CV 2/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.772, test=0.761) total time=   0.4s
# [CV 3/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 4/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 5/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 6/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 7/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 8/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 9/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 10/10] END learning_rate=0.35, max_delta_step=39, max_depth=10, n_estimators=820, subsample=0;, score=(train=0.771, test=0.769) total time=   0.4s
# [CV 1/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 2/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 3/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 4/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   1.4s
# [CV 5/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   1.5s
# [CV 6/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 7/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   1.2s
# [CV 8/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   1.4s
# [CV 9/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 10/10] END learning_rate=0.75, max_delta_step=32, max_depth=30, n_estimators=1840, subsample=0;, score=(train=0.771, test=0.769) total time=   0.9s
# [CV 1/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.772, test=0.761) total time=   0.7s
# [CV 2/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.772, test=0.761) total time=   1.0s
# [CV 3/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 4/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   1.2s
# [CV 5/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 6/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 7/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 8/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 9/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.774) total time=   1.0s
# [CV 10/10] END learning_rate=0.2, max_delta_step=38, max_depth=8, n_estimators=970, subsample=0;, score=(train=0.771, test=0.769) total time=   0.9s
# [CV 1/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 2/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 3/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 4/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 5/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 6/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 7/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   1.5s
# [CV 8/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   1.0s
# [CV 9/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 10/10] END learning_rate=0.35, max_delta_step=4, max_depth=4, n_estimators=1160, subsample=0;, score=(train=0.771, test=0.769) total time=   1.3s
# [CV 1/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 2/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.772, test=0.761) total time=   1.1s
# [CV 3/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   1.0s
# [CV 4/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 5/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 6/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 7/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 8/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 9/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 10/10] END learning_rate=0.4, max_delta_step=17, max_depth=34, n_estimators=980, subsample=0;, score=(train=0.771, test=0.769) total time=   1.0s
# [CV 1/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.772, test=0.761) total time=   0.6s
# [CV 2/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 3/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 4/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 5/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 6/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 7/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 8/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 9/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 10/10] END learning_rate=0.35, max_delta_step=2, max_depth=42, n_estimators=710, subsample=0;, score=(train=0.771, test=0.769) total time=   0.4s
# [CV 1/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.772, test=0.761) total time=   0.8s
# [CV 2/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.772, test=0.761) total time=   1.2s
# [CV 3/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 4/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   1.1s
# [CV 5/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 6/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   1.0s
# [CV 7/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 8/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   1.1s
# [CV 9/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 10/10] END learning_rate=0.35, max_delta_step=14, max_depth=8, n_estimators=1580, subsample=0;, score=(train=0.771, test=0.769) total time=   1.1s
# [CV 1/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.986) total time=   1.1s
# [CV 2/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.986) total time=   1.1s
# [CV 3/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.973) total time=   1.0s
# [CV 4/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.973) total time=   0.9s
# [CV 5/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.972) total time=   1.6s
# [CV 6/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.959) total time=   1.1s
# [CV 7/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.943) total time=   0.8s
# [CV 8/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=1.000) total time=   0.7s
# [CV 9/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 10/10] END learning_rate=0.5, max_delta_step=0, max_depth=26, n_estimators=1370, subsample=1;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 1/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   0.6s
# [CV 2/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   1.4s
# [CV 3/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   1.1s
# [CV 4/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.973) total time=   0.9s
# [CV 5/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 6/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.960) total time=   0.5s
# [CV 7/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.943) total time=   0.6s
# [CV 8/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.986) total time=   1.3s
# [CV 9/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.972) total time=   7.4s
# [CV 10/10] END learning_rate=0.75, max_delta_step=29, max_depth=12, n_estimators=1040, subsample=1;, score=(train=1.000, test=0.957) total time=   2.7s
# [CV 1/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.5s
# [CV 2/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 3/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 4/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 5/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 6/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.946) total time=   0.3s
# [CV 7/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.943) total time=   0.3s
# [CV 8/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=1.000) total time=   0.4s
# [CV 9/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 10/10] END learning_rate=0.6, max_delta_step=21, max_depth=44, n_estimators=660, subsample=1;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 1/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 2/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 3/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 4/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 5/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 6/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 7/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   0.4s
# [CV 8/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   1.0s
# [CV 9/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 10/10] END learning_rate=0.55, max_delta_step=46, max_depth=34, n_estimators=1000, subsample=0;, score=(train=0.771, test=0.769) total time=   0.4s
# [CV 1/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=0.972) total time=   1.0s
# [CV 2/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=1.000) total time=   0.7s
# [CV 3/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=1.000) total time=   0.6s
# [CV 4/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=0.973) total time=   0.7s
# [CV 5/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=1.000) total time=   0.8s
# [CV 6/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=0.959) total time=   0.6s
# [CV 7/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=0.943) total time=   1.4s
# [CV 8/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=1.000) total time=   1.1s
# [CV 9/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=0.986) total time=   0.8s
# [CV 10/10] END learning_rate=0.1, max_delta_step=18, max_depth=20, n_estimators=880, subsample=1;, score=(train=1.000, test=0.986) total time=   0.9s
# [CV 1/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.986) total time=   1.3s
# [CV 2/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.986) total time=   1.5s
# [CV 3/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.973) total time=   1.2s
# [CV 4/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.973) total time=   1.5s
# [CV 5/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.986) total time=   1.2s
# [CV 6/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.959) total time=   1.0s
# [CV 7/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.943) total time=   1.6s
# [CV 8/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.986) total time=   1.8s
# [CV 9/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.972) total time=   1.8s
# [CV 10/10] END learning_rate=0.65, max_delta_step=9, max_depth=38, n_estimators=1760, subsample=1;, score=(train=1.000, test=0.958) total time=   2.5s
# [CV 1/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.772, test=0.761) total time=   0.5s
# [CV 2/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.772, test=0.761) total time=   0.6s
# [CV 3/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 4/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.5s
# [CV 5/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 6/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.2s
# [CV 7/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 8/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 9/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.774) total time=   0.3s
# [CV 10/10] END learning_rate=0.85, max_delta_step=17, max_depth=24, n_estimators=590, subsample=0;, score=(train=0.771, test=0.769) total time=   0.3s
# [CV 1/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 2/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 3/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=1.000) total time=   0.3s
# [CV 4/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 5/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=1.000) total time=   0.3s
# [CV 6/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.946) total time=   0.2s
# [CV 7/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.943) total time=   0.2s
# [CV 8/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 9/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 10/10] END learning_rate=0.4, max_delta_step=29, max_depth=40, n_estimators=250, subsample=1;, score=(train=1.000, test=0.972) total time=   0.3s
# [CV 1/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.772, test=0.761) total time=   2.0s
# [CV 2/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.772, test=0.761) total time=   0.9s
# [CV 3/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   0.8s
# [CV 4/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   0.9s
# [CV 5/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   1.2s
# [CV 6/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   0.7s
# [CV 7/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 8/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   0.6s
# [CV 9/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.774) total time=   1.4s
# [CV 10/10] END learning_rate=0.75, max_delta_step=14, max_depth=2, n_estimators=1250, subsample=0;, score=(train=0.771, test=0.769) total time=   0.8s
# [CV 1/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.772, test=0.761) total time=   0.0s
# [CV 2/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.772, test=0.761) total time=   0.0s
# [CV 3/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 4/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 5/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 6/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 7/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 8/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 9/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 10/10] END learning_rate=0.4, max_delta_step=38, max_depth=10, n_estimators=20, subsample=0;, score=(train=0.771, test=0.769) total time=   0.0s
# 0.9819173310462139
# {'subsample': 1, 'n_estimators': 1670, 'max_depth': 12, 'max_delta_step': 40, 'learning_rate': 0.1}

# %%
### RANDOMIZED SEARCH FOR REGRESSION MODELS


#loading  theh datasets
reg_X = datasets.load_diabetes(as_frame=True)['data']
reg_y = datasets.load_diabetes()['target']

#instantiating the model
reg_xgb = XGBRegressor(random_state = 23, n_jobs = 1)

# setting up cross validation
fold = StratifiedKFold(n_splits=6, shuffle= True, random_state=32)

params = {
     'n_estimators': list(range(10,2000,10)),
    'learning_rate': [x/100 for x in range(10, 95, 5)],
    'max_depth' : list(range(2,50,2)),
    'colsample_bytree': [0,1],
    'subsample': [0,1],
    'colsample_bynode': [0,1],
    'lambda': list(range(1,10,1))
}


# setting up the model
reg_model = RandomizedSearchCV(estimator= reg_xgb, param_distributions= params,
                               n_iter= 10, scoring='neg_root_mean_squared_error',
                               n_jobs=1, cv = fold.split(reg_X, reg_y), verbose=3,
                               random_state=32, return_train_score= True)

reg_model.fit(reg_X, reg_y)

best_rmse = reg_model.best_score_
best_params = reg_model.best_params_
best_reg_model = reg_model.best_estimator_

for i in [best_rmse, best_params]:
    print(i)
# Out:
# c:\Users\hp\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=6.
#   warnings.warn(
# Fitting 6 folds for each of 10 candidates, totalling 60 fits
# [CV 1/6] END colsample_bynode=1, colsample_bytree=1, lambda=2, learning_rate=0.15, max_depth=42, n_estimators=1300, subsample=1;, score=(train=-0.001, test=-64.362) total time=   4.0s
# [CV 2/6] END colsample_bynode=1, colsample_bytree=1, lambda=2, learning_rate=0.15, max_depth=42, n_estimators=1300, subsample=1;, score=(train=-0.001, test=-62.894) total time=   2.6s
# [CV 3/6] END colsample_bynode=1, colsample_bytree=1, lambda=2, learning_rate=0.15, max_depth=42, n_estimators=1300, subsample=1;, score=(train=-0.001, test=-66.880) total time=   2.6s
# [CV 4/6] END colsample_bynode=1, colsample_bytree=1, lambda=2, learning_rate=0.15, max_depth=42, n_estimators=1300, subsample=1;, score=(train=-0.001, test=-64.575) total time=   2.5s
# [CV 5/6] END colsample_bynode=1, colsample_bytree=1, lambda=2, learning_rate=0.15, max_depth=42, n_estimators=1300, subsample=1;, score=(train=-0.001, test=-58.584) total time=   3.5s
# [CV 6/6] END colsample_bynode=1, colsample_bytree=1, lambda=2, learning_rate=0.15, max_depth=42, n_estimators=1300, subsample=1;, score=(train=-0.001, test=-68.079) total time=   2.4s
# [CV 1/6] END colsample_bynode=1, colsample_bytree=1, lambda=3, learning_rate=0.5, max_depth=42, n_estimators=720, subsample=0;, score=(train=-77.473, test=-74.711) total time=   0.3s
# [CV 2/6] END colsample_bynode=1, colsample_bytree=1, lambda=3, learning_rate=0.5, max_depth=42, n_estimators=720, subsample=0;, score=(train=-77.240, test=-75.838) total time=   0.1s
# [CV 3/6] END colsample_bynode=1, colsample_bytree=1, lambda=3, learning_rate=0.5, max_depth=42, n_estimators=720, subsample=0;, score=(train=-76.760, test=-78.396) total time=   0.3s
# [CV 4/6] END colsample_bynode=1, colsample_bytree=1, lambda=3, learning_rate=0.5, max_depth=42, n_estimators=720, subsample=0;, score=(train=-75.845, test=-82.601) total time=   0.2s
# [CV 5/6] END colsample_bynode=1, colsample_bytree=1, lambda=3, learning_rate=0.5, max_depth=42, n_estimators=720, subsample=0;, score=(train=-77.075, test=-76.663) total time=   0.6s
# [CV 6/6] END colsample_bynode=1, colsample_bytree=1, lambda=3, learning_rate=0.5, max_depth=42, n_estimators=720, subsample=0;, score=(train=-77.539, test=-74.437) total time=   0.8s
# [CV 1/6] END colsample_bynode=0, colsample_bytree=1, lambda=3, learning_rate=0.65, max_depth=22, n_estimators=90, subsample=0;, score=(train=-77.473, test=-74.711) total time=   0.1s
# [CV 2/6] END colsample_bynode=0, colsample_bytree=1, lambda=3, learning_rate=0.65, max_depth=22, n_estimators=90, subsample=0;, score=(train=-77.240, test=-75.838) total time=   0.4s
# [CV 3/6] END colsample_bynode=0, colsample_bytree=1, lambda=3, learning_rate=0.65, max_depth=22, n_estimators=90, subsample=0;, score=(train=-76.760, test=-78.396) total time=   0.0s
# [CV 4/6] END colsample_bynode=0, colsample_bytree=1, lambda=3, learning_rate=0.65, max_depth=22, n_estimators=90, subsample=0;, score=(train=-75.845, test=-82.601) total time=   0.0s
# [CV 5/6] END colsample_bynode=0, colsample_bytree=1, lambda=3, learning_rate=0.65, max_depth=22, n_estimators=90, subsample=0;, score=(train=-77.075, test=-76.663) total time=   0.0s
# [CV 6/6] END colsample_bynode=0, colsample_bytree=1, lambda=3, learning_rate=0.65, max_depth=22, n_estimators=90, subsample=0;, score=(train=-77.539, test=-74.437) total time=   0.0s
# [CV 1/6] END colsample_bynode=0, colsample_bytree=0, lambda=9, learning_rate=0.25, max_depth=18, n_estimators=1120, subsample=0;, score=(train=-77.473, test=-74.711) total time=   0.9s
# [CV 2/6] END colsample_bynode=0, colsample_bytree=0, lambda=9, learning_rate=0.25, max_depth=18, n_estimators=1120, subsample=0;, score=(train=-77.240, test=-75.838) total time=   1.3s
# [CV 3/6] END colsample_bynode=0, colsample_bytree=0, lambda=9, learning_rate=0.25, max_depth=18, n_estimators=1120, subsample=0;, score=(train=-76.760, test=-78.396) total time=   0.5s
# [CV 4/6] END colsample_bynode=0, colsample_bytree=0, lambda=9, learning_rate=0.25, max_depth=18, n_estimators=1120, subsample=0;, score=(train=-75.845, test=-82.601) total time=   0.4s
# [CV 5/6] END colsample_bynode=0, colsample_bytree=0, lambda=9, learning_rate=0.25, max_depth=18, n_estimators=1120, subsample=0;, score=(train=-77.075, test=-76.663) total time=   1.0s
# [CV 6/6] END colsample_bynode=0, colsample_bytree=0, lambda=9, learning_rate=0.25, max_depth=18, n_estimators=1120, subsample=0;, score=(train=-77.539, test=-74.437) total time=   0.7s
# [CV 1/6] END colsample_bynode=0, colsample_bytree=1, lambda=7, learning_rate=0.35, max_depth=4, n_estimators=1980, subsample=0;, score=(train=-77.473, test=-74.711) total time=   0.9s
# [CV 2/6] END colsample_bynode=0, colsample_bytree=1, lambda=7, learning_rate=0.35, max_depth=4, n_estimators=1980, subsample=0;, score=(train=-77.240, test=-75.838) total time=   0.5s
# [CV 3/6] END colsample_bynode=0, colsample_bytree=1, lambda=7, learning_rate=0.35, max_depth=4, n_estimators=1980, subsample=0;, score=(train=-76.760, test=-78.396) total time=   0.8s
# [CV 4/6] END colsample_bynode=0, colsample_bytree=1, lambda=7, learning_rate=0.35, max_depth=4, n_estimators=1980, subsample=0;, score=(train=-75.845, test=-82.601) total time=   0.7s
# [CV 5/6] END colsample_bynode=0, colsample_bytree=1, lambda=7, learning_rate=0.35, max_depth=4, n_estimators=1980, subsample=0;, score=(train=-77.075, test=-76.663) total time=   0.8s
# [CV 6/6] END colsample_bynode=0, colsample_bytree=1, lambda=7, learning_rate=0.35, max_depth=4, n_estimators=1980, subsample=0;, score=(train=-77.539, test=-74.437) total time=   0.5s
# [CV 1/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.4, max_depth=12, n_estimators=1670, subsample=1;, score=(train=-0.002, test=-78.555) total time=   1.8s
# [CV 2/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.4, max_depth=12, n_estimators=1670, subsample=1;, score=(train=-0.002, test=-67.630) total time=   1.7s
# [CV 3/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.4, max_depth=12, n_estimators=1670, subsample=1;, score=(train=-0.002, test=-70.580) total time=   1.6s
# [CV 4/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.4, max_depth=12, n_estimators=1670, subsample=1;, score=(train=-0.002, test=-76.055) total time=   1.7s
# [CV 5/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.4, max_depth=12, n_estimators=1670, subsample=1;, score=(train=-0.002, test=-72.125) total time=   1.5s
# [CV 6/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.4, max_depth=12, n_estimators=1670, subsample=1;, score=(train=-0.002, test=-72.281) total time=   1.6s
# [CV 1/6] END colsample_bynode=0, colsample_bytree=1, lambda=1, learning_rate=0.1, max_depth=26, n_estimators=1950, subsample=0;, score=(train=-77.473, test=-74.711) total time=   0.5s
# [CV 2/6] END colsample_bynode=0, colsample_bytree=1, lambda=1, learning_rate=0.1, max_depth=26, n_estimators=1950, subsample=0;, score=(train=-77.240, test=-75.838) total time=   0.5s
# [CV 3/6] END colsample_bynode=0, colsample_bytree=1, lambda=1, learning_rate=0.1, max_depth=26, n_estimators=1950, subsample=0;, score=(train=-76.760, test=-78.396) total time=   0.5s
# [CV 4/6] END colsample_bynode=0, colsample_bytree=1, lambda=1, learning_rate=0.1, max_depth=26, n_estimators=1950, subsample=0;, score=(train=-75.845, test=-82.601) total time=   0.5s
# [CV 5/6] END colsample_bynode=0, colsample_bytree=1, lambda=1, learning_rate=0.1, max_depth=26, n_estimators=1950, subsample=0;, score=(train=-77.075, test=-76.663) total time=   0.5s
# [CV 6/6] END colsample_bynode=0, colsample_bytree=1, lambda=1, learning_rate=0.1, max_depth=26, n_estimators=1950, subsample=0;, score=(train=-77.539, test=-74.437) total time=   0.5s
# [CV 1/6] END colsample_bynode=1, colsample_bytree=1, lambda=7, learning_rate=0.6, max_depth=26, n_estimators=240, subsample=1;, score=(train=-0.001, test=-63.716) total time=   0.7s
# [CV 2/6] END colsample_bynode=1, colsample_bytree=1, lambda=7, learning_rate=0.6, max_depth=26, n_estimators=240, subsample=1;, score=(train=-0.001, test=-62.237) total time=   0.8s
# [CV 3/6] END colsample_bynode=1, colsample_bytree=1, lambda=7, learning_rate=0.6, max_depth=26, n_estimators=240, subsample=1;, score=(train=-0.001, test=-63.444) total time=   0.7s
# [CV 4/6] END colsample_bynode=1, colsample_bytree=1, lambda=7, learning_rate=0.6, max_depth=26, n_estimators=240, subsample=1;, score=(train=-0.001, test=-65.133) total time=   0.9s
# [CV 5/6] END colsample_bynode=1, colsample_bytree=1, lambda=7, learning_rate=0.6, max_depth=26, n_estimators=240, subsample=1;, score=(train=-0.001, test=-56.540) total time=   0.9s
# [CV 6/6] END colsample_bynode=1, colsample_bytree=1, lambda=7, learning_rate=0.6, max_depth=26, n_estimators=240, subsample=1;, score=(train=-0.001, test=-66.832) total time=   0.7s
# [CV 1/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.3, max_depth=22, n_estimators=1190, subsample=1;, score=(train=-0.006, test=-79.783) total time=   2.2s
# [CV 2/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.3, max_depth=22, n_estimators=1190, subsample=1;, score=(train=-0.003, test=-68.742) total time=   2.1s
# [CV 3/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.3, max_depth=22, n_estimators=1190, subsample=1;, score=(train=-0.007, test=-71.926) total time=   2.1s
# [CV 4/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.3, max_depth=22, n_estimators=1190, subsample=1;, score=(train=-0.005, test=-75.733) total time=   2.1s
# [CV 5/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.3, max_depth=22, n_estimators=1190, subsample=1;, score=(train=-0.003, test=-71.685) total time=   1.9s
# [CV 6/6] END colsample_bynode=0, colsample_bytree=0, lambda=3, learning_rate=0.3, max_depth=22, n_estimators=1190, subsample=1;, score=(train=-0.002, test=-71.316) total time=   2.0s
# [CV 1/6] END colsample_bynode=1, colsample_bytree=0, lambda=6, learning_rate=0.3, max_depth=44, n_estimators=1040, subsample=1;, score=(train=-0.108, test=-80.895) total time=   1.6s
# [CV 2/6] END colsample_bynode=1, colsample_bytree=0, lambda=6, learning_rate=0.3, max_depth=44, n_estimators=1040, subsample=1;, score=(train=-0.053, test=-69.838) total time=   1.6s
# [CV 3/6] END colsample_bynode=1, colsample_bytree=0, lambda=6, learning_rate=0.3, max_depth=44, n_estimators=1040, subsample=1;, score=(train=-0.099, test=-74.680) total time=   1.7s
# [CV 4/6] END colsample_bynode=1, colsample_bytree=0, lambda=6, learning_rate=0.3, max_depth=44, n_estimators=1040, subsample=1;, score=(train=-0.097, test=-74.348) total time=   1.7s
# [CV 5/6] END colsample_bynode=1, colsample_bytree=0, lambda=6, learning_rate=0.3, max_depth=44, n_estimators=1040, subsample=1;, score=(train=-0.060, test=-72.981) total time=   1.5s
# [CV 6/6] END colsample_bynode=1, colsample_bytree=0, lambda=6, learning_rate=0.3, max_depth=44, n_estimators=1040, subsample=1;, score=(train=-0.041, test=-70.955) total time=   2.1s
# -62.98383802991871
# {'subsample': 1, 'n_estimators': 240, 'max_depth': 26, 'learning_rate': 0.6, 'lambda': 7, 'colsample_bytree': 1, 'colsample_bynode': 1}

# %%
# Out:
# [0.1,
#  0.15,
#  0.2,
#  0.25,
#  0.3,
#  0.35,
#  0.4,
#  0.45,
#  0.5,
#  0.55,
#  0.6,
#  0.65,
#  0.7,
#  0.75,
#  0.8,
#  0.85,
#  0.9]

# %%
nums
# Out:
# [0.1,
#  0.15,
#  0.2,
#  0.25,
#  0.3,
#  0.35,
#  0.4,
#  0.45,
#  0.5,
#  0.55,
#  0.6,
#  0.65,
#  0.7,
#  0.75,
#  0.8,
#  0.85,
#  0.9]
