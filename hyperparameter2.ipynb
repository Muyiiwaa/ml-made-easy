# %% [markdown]
# ### Hyperparameter Optimization
#
# 1. GridsearchCV
# 2. RandomizedSearch
# 3. Optuna
# 4. HyperOpt

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import f1_score, mean_squared_error


from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

from sklearn import datasets

# %%
data = datasets.load_diabetes(as_frame=True)['data']
y = datasets.load_diabetes()['target']

# %%
reg = RandomForestRegressor(random_state= 42, n_jobs= -1)

parameters = {
    
    'n_estimators': list(range(10,60,10)),
    'max_depth': list(range(2,12,2)),
    'criterion': ['squared_error','absolute_error'],
    'max_features': ['sqrt', 'log2']
}

model = GridSearchCV(estimator=reg, param_grid=parameters,
                     n_jobs= 1, cv=5, verbose=10, return_train_score= True,
                     scoring= 'neg_root_mean_squared_error')

model.fit(X = data, y = y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5; 1/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10
# [CV 1/5; 1/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10;, score=(train=-57.716, test=-61.483) total time=  20.9s
# [CV 2/5; 1/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10
# [CV 2/5; 1/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10;, score=(train=-58.455, test=-61.028) total time=   0.1s
# [CV 3/5; 1/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10
# [CV 3/5; 1/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10;, score=(train=-57.889, test=-62.206) total time=   0.6s
# [CV 4/5; 1/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10
# [CV 4/5; 1/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10;, score=(train=-57.974, test=-59.003) total time=   0.2s
# [CV 5/5; 1/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10
# [CV 5/5; 1/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=10;, score=(train=-57.195, test=-62.223) total time=   0.3s
# [CV 1/5; 2/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20
# [CV 1/5; 2/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20;, score=(train=-56.532, test=-60.086) total time=   0.4s
# [CV 2/5; 2/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20
# [CV 2/5; 2/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20;, score=(train=-57.091, test=-59.730) total time=   0.2s
# [CV 3/5; 2/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20
# [CV 3/5; 2/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20;, score=(train=-56.987, test=-61.207) total time=   0.5s
# [CV 4/5; 2/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20
# [CV 4/5; 2/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20;, score=(train=-57.166, test=-57.913) total time=   0.3s
# [CV 5/5; 2/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20
# [CV 5/5; 2/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=20;, score=(train=-56.399, test=-61.515) total time=   0.7s
# [CV 1/5; 3/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30
# [CV 1/5; 3/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30;, score=(train=-56.314, test=-60.254) total time=   0.3s
# [CV 2/5; 3/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30
# [CV 2/5; 3/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30;, score=(train=-57.098, test=-59.802) total time=   0.6s
# [CV 3/5; 3/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30
# [CV 3/5; 3/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30;, score=(train=-56.632, test=-60.829) total time=   0.4s
# [CV 4/5; 3/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30
# [CV 4/5; 3/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30;, score=(train=-56.842, test=-57.487) total time=   0.8s
# [CV 5/5; 3/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30
# [CV 5/5; 3/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=30;, score=(train=-56.407, test=-61.238) total time=   0.2s
# [CV 1/5; 4/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40
# [CV 1/5; 4/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40;, score=(train=-55.966, test=-59.019) total time=   0.3s
# [CV 2/5; 4/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40
# [CV 2/5; 4/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40;, score=(train=-56.637, test=-59.336) total time=   0.9s
# [CV 3/5; 4/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40
# [CV 3/5; 4/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40;, score=(train=-56.008, test=-60.285) total time=   0.8s
# [CV 4/5; 4/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40
# [CV 4/5; 4/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40;, score=(train=-56.508, test=-57.598) total time=   0.4s
# [CV 5/5; 4/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40
# [CV 5/5; 4/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=40;, score=(train=-55.956, test=-60.951) total time=   0.7s
# [CV 1/5; 5/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50
# [CV 1/5; 5/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50;, score=(train=-55.972, test=-58.904) total time=   0.4s
# [CV 2/5; 5/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50
# [CV 2/5; 5/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50;, score=(train=-56.465, test=-59.049) total time=   0.3s
# [CV 3/5; 5/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50
# [CV 3/5; 5/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50;, score=(train=-55.988, test=-59.948) total time=   0.9s
# [CV 4/5; 5/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50
# [CV 4/5; 5/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50;, score=(train=-56.460, test=-57.310) total time=   0.3s
# [CV 5/5; 5/100] START criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50
# [CV 5/5; 5/100] END criterion=squared_error, max_depth=2, max_features=sqrt, n_estimators=50;, score=(train=-56.005, test=-60.989) total time=   0.4s
# [CV 1/5; 6/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10
# [CV 1/5; 6/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10;, score=(train=-57.716, test=-61.483) total time=   0.1s
# [CV 2/5; 6/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10
# [CV 2/5; 6/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10;, score=(train=-58.455, test=-61.028) total time=   0.5s
# [CV 3/5; 6/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10
# [CV 3/5; 6/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10;, score=(train=-57.889, test=-62.206) total time=   0.2s
# [CV 4/5; 6/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10
# [CV 4/5; 6/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10;, score=(train=-57.974, test=-59.003) total time=   0.7s
# [CV 5/5; 6/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10
# [CV 5/5; 6/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=10;, score=(train=-57.195, test=-62.223) total time=   0.2s
# [CV 1/5; 7/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20
# [CV 1/5; 7/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20;, score=(train=-56.532, test=-60.086) total time=   0.8s
# [CV 2/5; 7/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20
# [CV 2/5; 7/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20;, score=(train=-57.091, test=-59.730) total time=   0.4s
# [CV 3/5; 7/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20
# [CV 3/5; 7/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20;, score=(train=-56.987, test=-61.207) total time=   0.1s
# [CV 4/5; 7/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20
# [CV 4/5; 7/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20;, score=(train=-57.166, test=-57.913) total time=   0.3s
# [CV 5/5; 7/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20
# [CV 5/5; 7/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=20;, score=(train=-56.399, test=-61.515) total time=   0.3s
# [CV 1/5; 8/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30
# [CV 1/5; 8/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30;, score=(train=-56.314, test=-60.254) total time=   0.0s
# [CV 2/5; 8/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30
# [CV 2/5; 8/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30;, score=(train=-57.098, test=-59.802) total time=   0.1s
# [CV 3/5; 8/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30
# [CV 3/5; 8/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30;, score=(train=-56.632, test=-60.829) total time=   0.1s
# [CV 4/5; 8/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30
# [CV 4/5; 8/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30;, score=(train=-56.842, test=-57.487) total time=   0.1s
# [CV 5/5; 8/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30
# [CV 5/5; 8/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=30;, score=(train=-56.407, test=-61.238) total time=   0.0s
# [CV 1/5; 9/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40
# [CV 1/5; 9/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40;, score=(train=-55.966, test=-59.019) total time=   0.2s
# [CV 2/5; 9/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40
# [CV 2/5; 9/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40;, score=(train=-56.637, test=-59.336) total time=   0.1s
# [CV 3/5; 9/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40
# [CV 3/5; 9/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40;, score=(train=-56.008, test=-60.285) total time=   0.6s
# [CV 4/5; 9/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40
# [CV 4/5; 9/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40;, score=(train=-56.508, test=-57.598) total time=   0.1s
# [CV 5/5; 9/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40
# [CV 5/5; 9/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=40;, score=(train=-55.956, test=-60.951) total time=   0.1s
# [CV 1/5; 10/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50
# [CV 1/5; 10/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50;, score=(train=-55.972, test=-58.904) total time=   0.1s
# [CV 2/5; 10/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50
# [CV 2/5; 10/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50;, score=(train=-56.465, test=-59.049) total time=   0.4s
# [CV 3/5; 10/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50
# [CV 3/5; 10/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50;, score=(train=-55.988, test=-59.948) total time=   0.3s
# [CV 4/5; 10/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50
# [CV 4/5; 10/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50;, score=(train=-56.460, test=-57.310) total time=   0.1s
# [CV 5/5; 10/100] START criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50
# [CV 5/5; 10/100] END criterion=squared_error, max_depth=2, max_features=log2, n_estimators=50;, score=(train=-56.005, test=-60.989) total time=   0.1s
# [CV 1/5; 11/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10
# [CV 1/5; 11/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10;, score=(train=-48.361, test=-58.150) total time=   0.5s
# [CV 2/5; 11/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10
# [CV 2/5; 11/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10;, score=(train=-49.608, test=-55.534) total time=   0.1s
# [CV 3/5; 11/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10
# [CV 3/5; 11/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10;, score=(train=-47.573, test=-59.057) total time=   0.0s
# [CV 4/5; 11/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10
# [CV 4/5; 11/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10;, score=(train=-49.290, test=-57.522) total time=   0.0s
# [CV 5/5; 11/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10
# [CV 5/5; 11/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=10;, score=(train=-48.211, test=-58.770) total time=   0.0s
# [CV 1/5; 12/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20
# [CV 1/5; 12/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20;, score=(train=-47.718, test=-56.663) total time=   0.6s
# [CV 2/5; 12/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20
# [CV 2/5; 12/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20;, score=(train=-48.181, test=-55.814) total time=   0.1s
# [CV 3/5; 12/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20
# [CV 3/5; 12/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20;, score=(train=-46.723, test=-58.450) total time=   0.1s
# [CV 4/5; 12/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20
# [CV 4/5; 12/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20;, score=(train=-48.103, test=-55.498) total time=   0.2s
# [CV 5/5; 12/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20
# [CV 5/5; 12/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=20;, score=(train=-47.469, test=-57.915) total time=   0.0s
# [CV 1/5; 13/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30
# [CV 1/5; 13/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30;, score=(train=-47.799, test=-56.990) total time=   0.1s
# [CV 2/5; 13/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30
# [CV 2/5; 13/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30;, score=(train=-48.454, test=-55.483) total time=   0.6s
# [CV 3/5; 13/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30
# [CV 3/5; 13/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30;, score=(train=-46.659, test=-58.354) total time=   0.0s
# [CV 4/5; 13/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30
# [CV 4/5; 13/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30;, score=(train=-47.998, test=-55.483) total time=   0.1s
# [CV 5/5; 13/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30
# [CV 5/5; 13/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=30;, score=(train=-47.221, test=-57.463) total time=   0.2s
# [CV 1/5; 14/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40
# [CV 1/5; 14/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40;, score=(train=-47.467, test=-56.562) total time=   0.1s
# [CV 2/5; 14/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40
# [CV 2/5; 14/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40;, score=(train=-48.179, test=-54.971) total time=   0.3s
# [CV 3/5; 14/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40
# [CV 3/5; 14/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40;, score=(train=-46.459, test=-58.533) total time=   0.3s
# [CV 4/5; 14/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40
# [CV 4/5; 14/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40;, score=(train=-47.422, test=-55.245) total time=   0.1s
# [CV 5/5; 14/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40
# [CV 5/5; 14/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=40;, score=(train=-46.707, test=-57.478) total time=   0.1s
# [CV 1/5; 15/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50
# [CV 1/5; 15/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50;, score=(train=-47.416, test=-56.639) total time=   0.5s
# [CV 2/5; 15/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50
# [CV 2/5; 15/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50;, score=(train=-47.813, test=-54.971) total time=   0.2s
# [CV 3/5; 15/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50
# [CV 3/5; 15/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50;, score=(train=-46.269, test=-58.052) total time=   0.3s
# [CV 4/5; 15/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50
# [CV 4/5; 15/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50;, score=(train=-47.070, test=-55.056) total time=   0.6s
# [CV 5/5; 15/100] START criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50
# [CV 5/5; 15/100] END criterion=squared_error, max_depth=4, max_features=sqrt, n_estimators=50;, score=(train=-46.661, test=-57.341) total time=   0.1s
# [CV 1/5; 16/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10
# [CV 1/5; 16/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10;, score=(train=-48.361, test=-58.150) total time=   0.0s
# [CV 2/5; 16/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10
# [CV 2/5; 16/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10;, score=(train=-49.608, test=-55.534) total time=   0.0s
# [CV 3/5; 16/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10
# [CV 3/5; 16/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10;, score=(train=-47.573, test=-59.057) total time=   0.0s
# [CV 4/5; 16/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10
# [CV 4/5; 16/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10;, score=(train=-49.290, test=-57.522) total time=   0.0s
# [CV 5/5; 16/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10
# [CV 5/5; 16/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=10;, score=(train=-48.211, test=-58.770) total time=   0.0s
# [CV 1/5; 17/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20
# [CV 1/5; 17/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20;, score=(train=-47.718, test=-56.663) total time=   0.3s
# [CV 2/5; 17/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20
# [CV 2/5; 17/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20;, score=(train=-48.181, test=-55.814) total time=   0.0s
# [CV 3/5; 17/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20
# [CV 3/5; 17/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20;, score=(train=-46.723, test=-58.450) total time=   0.0s
# [CV 4/5; 17/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20
# [CV 4/5; 17/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20;, score=(train=-48.103, test=-55.498) total time=   0.1s
# [CV 5/5; 17/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20
# [CV 5/5; 17/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=20;, score=(train=-47.469, test=-57.915) total time=   0.5s
# [CV 1/5; 18/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30
# [CV 1/5; 18/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30;, score=(train=-47.799, test=-56.990) total time=   0.0s
# [CV 2/5; 18/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30
# [CV 2/5; 18/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30;, score=(train=-48.454, test=-55.483) total time=   0.0s
# [CV 3/5; 18/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30
# [CV 3/5; 18/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30;, score=(train=-46.659, test=-58.354) total time=   0.0s
# [CV 4/5; 18/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30
# [CV 4/5; 18/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30;, score=(train=-47.998, test=-55.483) total time=   0.2s
# [CV 5/5; 18/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30
# [CV 5/5; 18/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=30;, score=(train=-47.221, test=-57.463) total time=   0.3s
# [CV 1/5; 19/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40
# [CV 1/5; 19/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40;, score=(train=-47.467, test=-56.562) total time=   0.2s
# [CV 2/5; 19/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40
# [CV 2/5; 19/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40;, score=(train=-48.179, test=-54.971) total time=   0.1s
# [CV 3/5; 19/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40
# [CV 3/5; 19/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40;, score=(train=-46.459, test=-58.533) total time=   0.1s
# [CV 4/5; 19/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40
# [CV 4/5; 19/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40;, score=(train=-47.422, test=-55.245) total time=   0.1s
# [CV 5/5; 19/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40
# [CV 5/5; 19/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=40;, score=(train=-46.707, test=-57.478) total time=   0.1s
# [CV 1/5; 20/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50
# [CV 1/5; 20/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50;, score=(train=-47.416, test=-56.639) total time=   0.2s
# [CV 2/5; 20/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50
# [CV 2/5; 20/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50;, score=(train=-47.813, test=-54.971) total time=   0.1s
# [CV 3/5; 20/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50
# [CV 3/5; 20/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50;, score=(train=-46.269, test=-58.052) total time=   0.2s
# [CV 4/5; 20/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50
# [CV 4/5; 20/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50;, score=(train=-47.070, test=-55.056) total time=   0.5s
# [CV 5/5; 20/100] START criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50
# [CV 5/5; 20/100] END criterion=squared_error, max_depth=4, max_features=log2, n_estimators=50;, score=(train=-46.661, test=-57.341) total time=   0.2s
# [CV 1/5; 21/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10
# [CV 1/5; 21/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10;, score=(train=-39.387, test=-56.270) total time=   0.0s
# [CV 2/5; 21/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10
# [CV 2/5; 21/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10;, score=(train=-40.167, test=-56.700) total time=   0.0s
# [CV 3/5; 21/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10
# [CV 3/5; 21/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10;, score=(train=-39.944, test=-60.868) total time=   0.5s
# [CV 4/5; 21/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10
# [CV 4/5; 21/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10;, score=(train=-40.498, test=-58.815) total time=   0.1s
# [CV 5/5; 21/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10
# [CV 5/5; 21/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=10;, score=(train=-39.573, test=-59.968) total time=   0.0s
# [CV 1/5; 22/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20
# [CV 1/5; 22/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20;, score=(train=-37.721, test=-56.369) total time=   0.0s
# [CV 2/5; 22/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20
# [CV 2/5; 22/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20;, score=(train=-38.783, test=-56.303) total time=   0.1s
# [CV 3/5; 22/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20
# [CV 3/5; 22/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20;, score=(train=-38.381, test=-58.462) total time=   0.5s
# [CV 4/5; 22/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20
# [CV 4/5; 22/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20;, score=(train=-37.923, test=-57.604) total time=   0.0s
# [CV 5/5; 22/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20
# [CV 5/5; 22/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=20;, score=(train=-38.396, test=-60.068) total time=   0.0s
# [CV 1/5; 23/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30
# [CV 1/5; 23/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30;, score=(train=-37.612, test=-57.024) total time=   0.1s
# [CV 2/5; 23/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30
# [CV 2/5; 23/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30;, score=(train=-38.280, test=-55.952) total time=   0.1s
# [CV 3/5; 23/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30
# [CV 3/5; 23/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30;, score=(train=-37.654, test=-58.465) total time=   0.2s
# [CV 4/5; 23/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30
# [CV 4/5; 23/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30;, score=(train=-37.280, test=-57.290) total time=   0.1s
# [CV 5/5; 23/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30
# [CV 5/5; 23/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=30;, score=(train=-38.070, test=-57.976) total time=   0.2s
# [CV 1/5; 24/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40
# [CV 1/5; 24/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40;, score=(train=-37.076, test=-56.193) total time=   0.3s
# [CV 2/5; 24/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40
# [CV 2/5; 24/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40;, score=(train=-38.047, test=-55.102) total time=   0.3s
# [CV 3/5; 24/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40
# [CV 3/5; 24/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40;, score=(train=-37.317, test=-58.724) total time=   0.1s
# [CV 4/5; 24/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40
# [CV 4/5; 24/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40;, score=(train=-37.048, test=-56.946) total time=   0.2s
# [CV 5/5; 24/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40
# [CV 5/5; 24/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=40;, score=(train=-37.471, test=-57.367) total time=   0.6s
# [CV 1/5; 25/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50
# [CV 1/5; 25/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50;, score=(train=-37.179, test=-55.833) total time=   0.4s
# [CV 2/5; 25/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50
# [CV 2/5; 25/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50;, score=(train=-37.829, test=-54.942) total time=   0.2s
# [CV 3/5; 25/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50
# [CV 3/5; 25/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50;, score=(train=-37.035, test=-58.692) total time=   0.1s
# [CV 4/5; 25/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50
# [CV 4/5; 25/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50;, score=(train=-36.940, test=-56.960) total time=   0.1s
# [CV 5/5; 25/100] START criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50
# [CV 5/5; 25/100] END criterion=squared_error, max_depth=6, max_features=sqrt, n_estimators=50;, score=(train=-37.439, test=-56.861) total time=   0.3s
# [CV 1/5; 26/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10
# [CV 1/5; 26/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10;, score=(train=-39.387, test=-56.270) total time=   0.0s
# [CV 2/5; 26/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10
# [CV 2/5; 26/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10;, score=(train=-40.167, test=-56.700) total time=   0.0s
# [CV 3/5; 26/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10
# [CV 3/5; 26/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10;, score=(train=-39.944, test=-60.868) total time=   0.2s
# [CV 4/5; 26/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10
# [CV 4/5; 26/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10;, score=(train=-40.498, test=-58.815) total time=   0.0s
# [CV 5/5; 26/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10
# [CV 5/5; 26/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=10;, score=(train=-39.573, test=-59.968) total time=   0.0s
# [CV 1/5; 27/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20
# [CV 1/5; 27/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20;, score=(train=-37.721, test=-56.369) total time=   0.1s
# [CV 2/5; 27/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20
# [CV 2/5; 27/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20;, score=(train=-38.783, test=-56.303) total time=   1.0s
# [CV 3/5; 27/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20
# [CV 3/5; 27/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20;, score=(train=-38.381, test=-58.462) total time=   0.1s
# [CV 4/5; 27/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20
# [CV 4/5; 27/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20;, score=(train=-37.923, test=-57.604) total time=   0.0s
# [CV 5/5; 27/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20
# [CV 5/5; 27/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=20;, score=(train=-38.396, test=-60.068) total time=   0.4s
# [CV 1/5; 28/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30
# [CV 1/5; 28/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30;, score=(train=-37.612, test=-57.024) total time=   0.4s
# [CV 2/5; 28/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30
# [CV 2/5; 28/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30;, score=(train=-38.280, test=-55.952) total time=   0.2s
# [CV 3/5; 28/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30
# [CV 3/5; 28/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30;, score=(train=-37.654, test=-58.465) total time=   0.7s
# [CV 4/5; 28/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30
# [CV 4/5; 28/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30;, score=(train=-37.280, test=-57.290) total time=   0.3s
# [CV 5/5; 28/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30
# [CV 5/5; 28/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=30;, score=(train=-38.070, test=-57.976) total time=   0.1s
# [CV 1/5; 29/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40
# [CV 1/5; 29/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40;, score=(train=-37.076, test=-56.193) total time=   0.9s
# [CV 2/5; 29/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40
# [CV 2/5; 29/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40;, score=(train=-38.047, test=-55.102) total time=   0.2s
# [CV 3/5; 29/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40
# [CV 3/5; 29/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40;, score=(train=-37.317, test=-58.724) total time=   0.1s
# [CV 4/5; 29/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40
# [CV 4/5; 29/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40;, score=(train=-37.048, test=-56.946) total time=   0.8s
# [CV 5/5; 29/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40
# [CV 5/5; 29/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=40;, score=(train=-37.471, test=-57.367) total time=   0.1s
# [CV 1/5; 30/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50
# [CV 1/5; 30/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50;, score=(train=-37.179, test=-55.833) total time=   0.4s
# [CV 2/5; 30/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50
# [CV 2/5; 30/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50;, score=(train=-37.829, test=-54.942) total time=   0.3s
# [CV 3/5; 30/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50
# [CV 3/5; 30/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50;, score=(train=-37.035, test=-58.692) total time=   0.1s
# [CV 4/5; 30/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50
# [CV 4/5; 30/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50;, score=(train=-36.940, test=-56.960) total time=   0.5s
# [CV 5/5; 30/100] START criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50
# [CV 5/5; 30/100] END criterion=squared_error, max_depth=6, max_features=log2, n_estimators=50;, score=(train=-37.439, test=-56.861) total time=   0.1s
# [CV 1/5; 31/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10
# [CV 1/5; 31/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10;, score=(train=-32.515, test=-58.683) total time=   0.0s
# [CV 2/5; 31/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10
# [CV 2/5; 31/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10;, score=(train=-31.529, test=-59.480) total time=   0.6s
# [CV 3/5; 31/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10
# [CV 3/5; 31/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10;, score=(train=-32.433, test=-64.561) total time=   0.0s
# [CV 4/5; 31/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10
# [CV 4/5; 31/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10;, score=(train=-31.981, test=-59.570) total time=   0.1s
# [CV 5/5; 31/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10
# [CV 5/5; 31/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=10;, score=(train=-32.462, test=-60.017) total time=   0.0s
# [CV 1/5; 32/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20
# [CV 1/5; 32/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20;, score=(train=-30.184, test=-58.629) total time=   0.1s
# [CV 2/5; 32/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20
# [CV 2/5; 32/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20;, score=(train=-30.740, test=-59.361) total time=   0.1s
# [CV 3/5; 32/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20
# [CV 3/5; 32/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20;, score=(train=-30.482, test=-60.328) total time=   0.2s
# [CV 4/5; 32/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20
# [CV 4/5; 32/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20;, score=(train=-29.805, test=-57.970) total time=   0.1s
# [CV 5/5; 32/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20
# [CV 5/5; 32/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=20;, score=(train=-30.131, test=-58.480) total time=   0.1s
# [CV 1/5; 33/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30
# [CV 1/5; 33/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30;, score=(train=-29.483, test=-58.429) total time=   0.2s
# [CV 2/5; 33/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30
# [CV 2/5; 33/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30;, score=(train=-29.916, test=-57.674) total time=   0.1s
# [CV 3/5; 33/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30
# [CV 3/5; 33/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30;, score=(train=-29.390, test=-60.365) total time=   0.0s
# [CV 4/5; 33/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30
# [CV 4/5; 33/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30;, score=(train=-29.034, test=-57.714) total time=   0.7s
# [CV 5/5; 33/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30
# [CV 5/5; 33/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=30;, score=(train=-29.313, test=-58.309) total time=   0.1s
# [CV 1/5; 34/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40
# [CV 1/5; 34/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40;, score=(train=-29.120, test=-58.864) total time=   0.1s
# [CV 2/5; 34/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40
# [CV 2/5; 34/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40;, score=(train=-29.394, test=-58.137) total time=   0.1s
# [CV 3/5; 34/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40
# [CV 3/5; 34/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40;, score=(train=-29.137, test=-59.548) total time=   0.5s
# [CV 4/5; 34/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40
# [CV 4/5; 34/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40;, score=(train=-28.612, test=-58.169) total time=   0.3s
# [CV 5/5; 34/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40
# [CV 5/5; 34/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=40;, score=(train=-28.961, test=-57.944) total time=   0.3s
# [CV 1/5; 35/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50
# [CV 1/5; 35/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50;, score=(train=-28.964, test=-58.385) total time=   0.6s
# [CV 2/5; 35/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50
# [CV 2/5; 35/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50;, score=(train=-28.933, test=-57.282) total time=   0.2s
# [CV 3/5; 35/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50
# [CV 3/5; 35/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50;, score=(train=-29.004, test=-59.242) total time=   0.2s
# [CV 4/5; 35/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50
# [CV 4/5; 35/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50;, score=(train=-28.620, test=-57.501) total time=   0.3s
# [CV 5/5; 35/100] START criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50
# [CV 5/5; 35/100] END criterion=squared_error, max_depth=8, max_features=sqrt, n_estimators=50;, score=(train=-28.849, test=-57.189) total time=   0.6s
# [CV 1/5; 36/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10
# [CV 1/5; 36/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10;, score=(train=-32.515, test=-58.683) total time=   0.0s
# [CV 2/5; 36/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10
# [CV 2/5; 36/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10;, score=(train=-31.529, test=-59.480) total time=   0.1s
# [CV 3/5; 36/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10
# [CV 3/5; 36/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10;, score=(train=-32.433, test=-64.561) total time=   0.8s
# [CV 4/5; 36/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10
# [CV 4/5; 36/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10;, score=(train=-31.981, test=-59.570) total time=   0.1s
# [CV 5/5; 36/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10
# [CV 5/5; 36/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=10;, score=(train=-32.462, test=-60.017) total time=   0.0s
# [CV 1/5; 37/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20
# [CV 1/5; 37/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20;, score=(train=-30.184, test=-58.629) total time=   0.6s
# [CV 2/5; 37/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20
# [CV 2/5; 37/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20;, score=(train=-30.740, test=-59.361) total time=   0.0s
# [CV 3/5; 37/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20
# [CV 3/5; 37/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20;, score=(train=-30.482, test=-60.328) total time=   0.2s
# [CV 4/5; 37/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20
# [CV 4/5; 37/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20;, score=(train=-29.805, test=-57.970) total time=   0.6s
# [CV 5/5; 37/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20
# [CV 5/5; 37/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=20;, score=(train=-30.131, test=-58.480) total time=   0.1s
# [CV 1/5; 38/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30
# [CV 1/5; 38/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-29.483, test=-58.429) total time=   0.3s
# [CV 2/5; 38/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30
# [CV 2/5; 38/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-29.916, test=-57.674) total time=   0.2s
# [CV 3/5; 38/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30
# [CV 3/5; 38/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-29.390, test=-60.365) total time=   0.8s
# [CV 4/5; 38/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30
# [CV 4/5; 38/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-29.034, test=-57.714) total time=   0.1s
# [CV 5/5; 38/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30
# [CV 5/5; 38/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-29.313, test=-58.309) total time=   0.1s
# [CV 1/5; 39/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 1/5; 39/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-29.120, test=-58.864) total time=   0.6s
# [CV 2/5; 39/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 2/5; 39/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-29.394, test=-58.137) total time=   0.4s
# [CV 3/5; 39/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 3/5; 39/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-29.137, test=-59.548) total time=   0.1s
# [CV 4/5; 39/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 4/5; 39/100] END criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-28.612, test=-58.169) total time=   1.0s
# [CV 5/5; 39/100] START criterion=squared_error, max_depth=8, max_features=log2, n_estimators=40
# ...
# [CV 4/5; 88/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-32.582, test=-55.066) total time=   0.1s
# [CV 5/5; 88/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=30
# [CV 5/5; 88/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=30;, score=(train=-32.268, test=-58.402) total time=   0.1s
# [CV 1/5; 89/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 1/5; 89/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-31.254, test=-56.925) total time=   0.5s
# [CV 2/5; 89/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 2/5; 89/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-32.325, test=-54.611) total time=   0.2s
# [CV 3/5; 89/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 3/5; 89/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-31.076, test=-58.945) total time=   0.2s
# [CV 4/5; 89/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 4/5; 89/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-32.283, test=-55.809) total time=   0.5s
# [CV 5/5; 89/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40
# [CV 5/5; 89/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=40;, score=(train=-31.433, test=-57.741) total time=   0.2s
# [CV 1/5; 90/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50
# [CV 1/5; 90/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50;, score=(train=-30.944, test=-56.937) total time=   0.3s
# [CV 2/5; 90/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50
# [CV 2/5; 90/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50;, score=(train=-32.075, test=-53.981) total time=   0.6s
# [CV 3/5; 90/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50
# [CV 3/5; 90/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50;, score=(train=-31.107, test=-58.429) total time=   0.5s
# [CV 4/5; 90/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50
# [CV 4/5; 90/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50;, score=(train=-31.948, test=-55.588) total time=   0.6s
# [CV 5/5; 90/100] START criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50
# [CV 5/5; 90/100] END criterion=absolute_error, max_depth=8, max_features=log2, n_estimators=50;, score=(train=-31.364, test=-58.150) total time=   0.5s
# [CV 1/5; 91/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 1/5; 91/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10;, score=(train=-29.373, test=-60.666) total time=   0.0s
# [CV 2/5; 91/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 2/5; 91/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10;, score=(train=-32.019, test=-60.538) total time=   0.0s
# [CV 3/5; 91/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 3/5; 91/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10;, score=(train=-30.071, test=-62.198) total time=   0.0s
# [CV 4/5; 91/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 4/5; 91/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10;, score=(train=-32.348, test=-60.759) total time=   0.5s
# [CV 5/5; 91/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 5/5; 91/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=10;, score=(train=-32.132, test=-60.005) total time=   0.1s
# [CV 1/5; 92/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20
# [CV 1/5; 92/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20;, score=(train=-27.633, test=-58.509) total time=   0.1s
# [CV 2/5; 92/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20
# [CV 2/5; 92/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20;, score=(train=-29.320, test=-59.115) total time=   0.0s
# [CV 3/5; 92/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20
# [CV 3/5; 92/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20;, score=(train=-27.947, test=-59.192) total time=   0.4s
# [CV 4/5; 92/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20
# [CV 4/5; 92/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20;, score=(train=-29.979, test=-57.359) total time=   0.1s
# [CV 5/5; 92/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20
# [CV 5/5; 92/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=20;, score=(train=-28.725, test=-58.537) total time=   0.1s
# [CV 1/5; 93/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30
# [CV 1/5; 93/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30;, score=(train=-27.830, test=-58.141) total time=   0.5s
# [CV 2/5; 93/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30
# [CV 2/5; 93/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30;, score=(train=-28.345, test=-57.496) total time=   0.1s
# [CV 3/5; 93/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30
# [CV 3/5; 93/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30;, score=(train=-27.069, test=-59.142) total time=   0.1s
# [CV 4/5; 93/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30
# [CV 4/5; 93/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30;, score=(train=-28.392, test=-56.901) total time=   0.1s
# [CV 5/5; 93/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30
# [CV 5/5; 93/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=30;, score=(train=-28.499, test=-57.542) total time=   0.4s
# [CV 1/5; 94/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40
# [CV 1/5; 94/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40;, score=(train=-27.430, test=-57.203) total time=   0.2s
# [CV 2/5; 94/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40
# [CV 2/5; 94/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40;, score=(train=-27.878, test=-56.085) total time=   0.1s
# [CV 3/5; 94/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40
# [CV 3/5; 94/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40;, score=(train=-26.755, test=-59.077) total time=   0.5s
# [CV 4/5; 94/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40
# [CV 4/5; 94/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40;, score=(train=-27.602, test=-57.323) total time=   0.1s
# [CV 5/5; 94/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40
# [CV 5/5; 94/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=40;, score=(train=-27.682, test=-58.097) total time=   0.4s
# [CV 1/5; 95/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 1/5; 95/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50;, score=(train=-27.043, test=-56.857) total time=   0.6s
# [CV 2/5; 95/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 2/5; 95/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50;, score=(train=-27.501, test=-55.986) total time=   0.5s
# [CV 3/5; 95/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 3/5; 95/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50;, score=(train=-26.634, test=-58.754) total time=   0.5s
# [CV 4/5; 95/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 4/5; 95/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50;, score=(train=-27.097, test=-56.800) total time=   0.3s
# [CV 5/5; 95/100] START criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 5/5; 95/100] END criterion=absolute_error, max_depth=10, max_features=sqrt, n_estimators=50;, score=(train=-27.192, test=-57.935) total time=   0.6s
# [CV 1/5; 96/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10
# [CV 1/5; 96/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10;, score=(train=-29.373, test=-60.666) total time=   0.0s
# [CV 2/5; 96/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10
# [CV 2/5; 96/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10;, score=(train=-32.019, test=-60.538) total time=   0.0s
# [CV 3/5; 96/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10
# [CV 3/5; 96/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10;, score=(train=-30.071, test=-62.198) total time=   0.0s
# [CV 4/5; 96/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10
# [CV 4/5; 96/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10;, score=(train=-32.348, test=-60.759) total time=   0.0s
# [CV 5/5; 96/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10
# [CV 5/5; 96/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=10;, score=(train=-32.132, test=-60.005) total time=   0.4s
# [CV 1/5; 97/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20
# [CV 1/5; 97/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20;, score=(train=-27.633, test=-58.509) total time=   0.0s
# [CV 2/5; 97/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20
# [CV 2/5; 97/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20;, score=(train=-29.320, test=-59.115) total time=   0.1s
# [CV 3/5; 97/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20
# [CV 3/5; 97/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20;, score=(train=-27.947, test=-59.192) total time=   0.5s
# [CV 4/5; 97/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20
# [CV 4/5; 97/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20;, score=(train=-29.979, test=-57.359) total time=   0.1s
# [CV 5/5; 97/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20
# [CV 5/5; 97/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=20;, score=(train=-28.725, test=-58.537) total time=   0.3s
# [CV 1/5; 98/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30
# [CV 1/5; 98/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30;, score=(train=-27.830, test=-58.141) total time=   0.1s
# [CV 2/5; 98/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30
# [CV 2/5; 98/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30;, score=(train=-28.345, test=-57.496) total time=   0.1s
# [CV 3/5; 98/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30
# [CV 3/5; 98/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30;, score=(train=-27.069, test=-59.142) total time=   0.4s
# [CV 4/5; 98/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30
# [CV 4/5; 98/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30;, score=(train=-28.392, test=-56.901) total time=   0.1s
# [CV 5/5; 98/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30
# [CV 5/5; 98/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=30;, score=(train=-28.499, test=-57.542) total time=   0.4s
# [CV 1/5; 99/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40
# [CV 1/5; 99/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40;, score=(train=-27.430, test=-57.203) total time=   0.6s
# [CV 2/5; 99/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40
# [CV 2/5; 99/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40;, score=(train=-27.878, test=-56.085) total time=   0.3s
# [CV 3/5; 99/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40
# [CV 3/5; 99/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40;, score=(train=-26.755, test=-59.077) total time=   0.4s
# [CV 4/5; 99/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40
# [CV 4/5; 99/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40;, score=(train=-27.602, test=-57.323) total time=   0.2s
# [CV 5/5; 99/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40
# [CV 5/5; 99/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=40;, score=(train=-27.682, test=-58.097) total time=   0.3s
# [CV 1/5; 100/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50
# [CV 1/5; 100/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50;, score=(train=-27.043, test=-56.857) total time=   0.6s
# [CV 2/5; 100/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50
# [CV 2/5; 100/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50;, score=(train=-27.501, test=-55.986) total time=   0.6s
# [CV 3/5; 100/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50
# [CV 3/5; 100/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50;, score=(train=-26.634, test=-58.754) total time=   0.3s
# [CV 4/5; 100/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50
# [CV 4/5; 100/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50;, score=(train=-27.097, test=-56.800) total time=   0.5s
# [CV 5/5; 100/100] START criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50
# [CV 5/5; 100/100] END criterion=absolute_error, max_depth=10, max_features=log2, n_estimators=50;, score=(train=-27.192, test=-57.935) total time=   0.4s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1, random_state=42),
#              n_jobs=1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 20, 30, 40, 50]},
#              return_train_score=True, scoring='neg_root_mean_squared_error',
#              verbose=10)

# %%
model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'n_estimators': 50}

# %%
model.best_score_
# Out:
# -56.41173460834938

# %%
model.best_estimator_
# Out:
# RandomForestRegressor(max_depth=4, max_features='sqrt', n_estimators=50,
#                       n_jobs=-1, random_state=42)

# %%
model.best_index_
# Out:
# 14

# %% [markdown]
# ### Classification

# %%
data = datasets.load_breast_cancer(as_frame=True)['data']
y = datasets.load_breast_cancer()['target']


classifier = RandomForestClassifier(random_state= 2, n_jobs= 1)


param_grid = {
    'n_estimators': list(range(10,60,10)),
    'max_depth': list(range(2,12, 2)),
    'criterion' : ['gini', 'entropy']
}

model_classifier = GridSearchCV(estimator= classifier, param_grid=param_grid,
                                scoring='f1',n_jobs=1, verbose = 10,
                                cv = 5, return_train_score=True
                                )
model_classifier.fit(data, y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5; 1/50] START criterion=gini, max_depth=2, n_estimators=10...............
# [CV 1/5; 1/50] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.976, test=0.945) total time=   0.0s
# [CV 2/5; 1/50] START criterion=gini, max_depth=2, n_estimators=10...............
# [CV 2/5; 1/50] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.970, test=0.939) total time=   0.0s
# [CV 3/5; 1/50] START criterion=gini, max_depth=2, n_estimators=10...............
# [CV 3/5; 1/50] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.960, test=0.966) total time=   0.1s
# [CV 4/5; 1/50] START criterion=gini, max_depth=2, n_estimators=10...............
# [CV 4/5; 1/50] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.960, test=0.966) total time=   0.1s
# [CV 5/5; 1/50] START criterion=gini, max_depth=2, n_estimators=10...............
# [CV 5/5; 1/50] END criterion=gini, max_depth=2, n_estimators=10;, score=(train=0.969, test=0.965) total time=   0.1s
# [CV 1/5; 2/50] START criterion=gini, max_depth=2, n_estimators=20...............
# [CV 1/5; 2/50] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.972, test=0.959) total time=   0.1s
# [CV 2/5; 2/50] START criterion=gini, max_depth=2, n_estimators=20...............
# [CV 2/5; 2/50] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.971, test=0.945) total time=   0.3s
# [CV 3/5; 2/50] START criterion=gini, max_depth=2, n_estimators=20...............
# [CV 3/5; 2/50] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.965, test=0.966) total time=   0.3s
# [CV 4/5; 2/50] START criterion=gini, max_depth=2, n_estimators=20...............
# [CV 4/5; 2/50] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.965, test=0.973) total time=   0.2s
# [CV 5/5; 2/50] START criterion=gini, max_depth=2, n_estimators=20...............
# [CV 5/5; 2/50] END criterion=gini, max_depth=2, n_estimators=20;, score=(train=0.969, test=0.971) total time=   0.3s
# [CV 1/5; 3/50] START criterion=gini, max_depth=2, n_estimators=30...............
# [CV 1/5; 3/50] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.974, test=0.952) total time=   0.5s
# [CV 2/5; 3/50] START criterion=gini, max_depth=2, n_estimators=30...............
# [CV 2/5; 3/50] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.977, test=0.939) total time=   0.4s
# [CV 3/5; 3/50] START criterion=gini, max_depth=2, n_estimators=30...............
# [CV 3/5; 3/50] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.964, test=0.972) total time=   0.4s
# [CV 4/5; 3/50] START criterion=gini, max_depth=2, n_estimators=30...............
# [CV 4/5; 3/50] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.970, test=0.973) total time=   0.3s
# [CV 5/5; 3/50] START criterion=gini, max_depth=2, n_estimators=30...............
# [CV 5/5; 3/50] END criterion=gini, max_depth=2, n_estimators=30;, score=(train=0.969, test=0.971) total time=   0.4s
# [CV 1/5; 4/50] START criterion=gini, max_depth=2, n_estimators=40...............
# [CV 1/5; 4/50] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.972, test=0.945) total time=   0.4s
# [CV 2/5; 4/50] START criterion=gini, max_depth=2, n_estimators=40...............
# [CV 2/5; 4/50] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.974, test=0.945) total time=   0.6s
# [CV 3/5; 4/50] START criterion=gini, max_depth=2, n_estimators=40...............
# [CV 3/5; 4/50] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.962, test=0.972) total time=   0.6s
# [CV 4/5; 4/50] START criterion=gini, max_depth=2, n_estimators=40...............
# [CV 4/5; 4/50] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.970, test=0.973) total time=   0.4s
# [CV 5/5; 4/50] START criterion=gini, max_depth=2, n_estimators=40...............
# [CV 5/5; 4/50] END criterion=gini, max_depth=2, n_estimators=40;, score=(train=0.969, test=0.971) total time=   0.5s
# [CV 1/5; 5/50] START criterion=gini, max_depth=2, n_estimators=50...............
# [CV 1/5; 5/50] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.971, test=0.952) total time=   0.5s
# [CV 2/5; 5/50] START criterion=gini, max_depth=2, n_estimators=50...............
# [CV 2/5; 5/50] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.976, test=0.945) total time=   0.4s
# [CV 3/5; 5/50] START criterion=gini, max_depth=2, n_estimators=50...............
# [CV 3/5; 5/50] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.962, test=0.972) total time=   0.5s
# [CV 4/5; 5/50] START criterion=gini, max_depth=2, n_estimators=50...............
# [CV 4/5; 5/50] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.970, test=0.973) total time=   0.5s
# [CV 5/5; 5/50] START criterion=gini, max_depth=2, n_estimators=50...............
# [CV 5/5; 5/50] END criterion=gini, max_depth=2, n_estimators=50;, score=(train=0.967, test=0.971) total time=   0.5s
# [CV 1/5; 6/50] START criterion=gini, max_depth=4, n_estimators=10...............
# [CV 1/5; 6/50] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.991, test=0.935) total time=   0.0s
# [CV 2/5; 6/50] START criterion=gini, max_depth=4, n_estimators=10...............
# [CV 2/5; 6/50] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.986, test=0.959) total time=   0.1s
# [CV 3/5; 6/50] START criterion=gini, max_depth=4, n_estimators=10...............
# [CV 3/5; 6/50] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.988, test=0.979) total time=   0.1s
# [CV 4/5; 6/50] START criterion=gini, max_depth=4, n_estimators=10...............
# [CV 4/5; 6/50] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.993, test=0.951) total time=   0.0s
# [CV 5/5; 6/50] START criterion=gini, max_depth=4, n_estimators=10...............
# [CV 5/5; 6/50] END criterion=gini, max_depth=4, n_estimators=10;, score=(train=0.984, test=0.978) total time=   0.1s
# [CV 1/5; 7/50] START criterion=gini, max_depth=4, n_estimators=20...............
# [CV 1/5; 7/50] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.990, test=0.950) total time=   0.3s
# [CV 2/5; 7/50] START criterion=gini, max_depth=4, n_estimators=20...............
# [CV 2/5; 7/50] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.988, test=0.959) total time=   0.2s
# [CV 3/5; 7/50] START criterion=gini, max_depth=4, n_estimators=20...............
# [CV 3/5; 7/50] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.988, test=0.986) total time=   0.3s
# [CV 4/5; 7/50] START criterion=gini, max_depth=4, n_estimators=20...............
# [CV 4/5; 7/50] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.993, test=0.966) total time=   0.3s
# [CV 5/5; 7/50] START criterion=gini, max_depth=4, n_estimators=20...............
# [CV 5/5; 7/50] END criterion=gini, max_depth=4, n_estimators=20;, score=(train=0.993, test=0.979) total time=   0.1s
# [CV 1/5; 8/50] START criterion=gini, max_depth=4, n_estimators=30...............
# [CV 1/5; 8/50] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.951) total time=   0.4s
# [CV 2/5; 8/50] START criterion=gini, max_depth=4, n_estimators=30...............
# [CV 2/5; 8/50] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.959) total time=   0.3s
# [CV 3/5; 8/50] START criterion=gini, max_depth=4, n_estimators=30...............
# [CV 3/5; 8/50] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.988, test=0.979) total time=   0.3s
# [CV 4/5; 8/50] START criterion=gini, max_depth=4, n_estimators=30...............
# [CV 4/5; 8/50] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.980) total time=   0.3s
# [CV 5/5; 8/50] START criterion=gini, max_depth=4, n_estimators=30...............
# [CV 5/5; 8/50] END criterion=gini, max_depth=4, n_estimators=30;, score=(train=0.990, test=0.979) total time=   0.4s
# [CV 1/5; 9/50] START criterion=gini, max_depth=4, n_estimators=40...............
# [CV 1/5; 9/50] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.944) total time=   0.6s
# [CV 2/5; 9/50] START criterion=gini, max_depth=4, n_estimators=40...............
# [CV 2/5; 9/50] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.959) total time=   0.6s
# [CV 3/5; 9/50] START criterion=gini, max_depth=4, n_estimators=40...............
# [CV 3/5; 9/50] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.988, test=0.979) total time=   0.5s
# [CV 4/5; 9/50] START criterion=gini, max_depth=4, n_estimators=40...............
# [CV 4/5; 9/50] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.973) total time=   0.5s
# [CV 5/5; 9/50] START criterion=gini, max_depth=4, n_estimators=40...............
# [CV 5/5; 9/50] END criterion=gini, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.972) total time=   0.6s
# [CV 1/5; 10/50] START criterion=gini, max_depth=4, n_estimators=50..............
# [CV 1/5; 10/50] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.990, test=0.944) total time=   0.6s
# [CV 2/5; 10/50] START criterion=gini, max_depth=4, n_estimators=50..............
# [CV 2/5; 10/50] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.959) total time=   0.7s
# [CV 3/5; 10/50] START criterion=gini, max_depth=4, n_estimators=50..............
# [CV 3/5; 10/50] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.988, test=0.986) total time=   0.6s
# [CV 4/5; 10/50] START criterion=gini, max_depth=4, n_estimators=50..............
# [CV 4/5; 10/50] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.980) total time=   0.6s
# [CV 5/5; 10/50] START criterion=gini, max_depth=4, n_estimators=50..............
# [CV 5/5; 10/50] END criterion=gini, max_depth=4, n_estimators=50;, score=(train=0.995, test=0.972) total time=   0.7s
# [CV 1/5; 11/50] START criterion=gini, max_depth=6, n_estimators=10..............
# [CV 1/5; 11/50] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.998, test=0.936) total time=   0.0s
# [CV 2/5; 11/50] START criterion=gini, max_depth=6, n_estimators=10..............
# [CV 2/5; 11/50] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.993, test=0.952) total time=   0.1s
# [CV 3/5; 11/50] START criterion=gini, max_depth=6, n_estimators=10..............
# [CV 3/5; 11/50] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.991, test=0.979) total time=   0.0s
# [CV 4/5; 11/50] START criterion=gini, max_depth=6, n_estimators=10..............
# [CV 4/5; 11/50] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.993, test=0.966) total time=   0.2s
# [CV 5/5; 11/50] START criterion=gini, max_depth=6, n_estimators=10..............
# [CV 5/5; 11/50] END criterion=gini, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.986) total time=   0.0s
# [CV 1/5; 12/50] START criterion=gini, max_depth=6, n_estimators=20..............
# [CV 1/5; 12/50] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.997, test=0.929) total time=   0.3s
# [CV 2/5; 12/50] START criterion=gini, max_depth=6, n_estimators=20..............
# [CV 2/5; 12/50] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.993, test=0.952) total time=   0.2s
# [CV 3/5; 12/50] START criterion=gini, max_depth=6, n_estimators=20..............
# [CV 3/5; 12/50] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.993, test=0.979) total time=   0.3s
# [CV 4/5; 12/50] START criterion=gini, max_depth=6, n_estimators=20..............
# [CV 4/5; 12/50] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.959) total time=   0.2s
# [CV 5/5; 12/50] START criterion=gini, max_depth=6, n_estimators=20..............
# [CV 5/5; 12/50] END criterion=gini, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.986) total time=   0.2s
# [CV 1/5; 13/50] START criterion=gini, max_depth=6, n_estimators=30..............
# [CV 1/5; 13/50] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.997, test=0.944) total time=   0.4s
# [CV 2/5; 13/50] START criterion=gini, max_depth=6, n_estimators=30..............
# [CV 2/5; 13/50] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.997, test=0.959) total time=   0.3s
# [CV 3/5; 13/50] START criterion=gini, max_depth=6, n_estimators=30..............
# [CV 3/5; 13/50] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.995, test=0.979) total time=   0.4s
# [CV 4/5; 13/50] START criterion=gini, max_depth=6, n_estimators=30..............
# [CV 4/5; 13/50] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.997, test=0.966) total time=   0.4s
# [CV 5/5; 13/50] START criterion=gini, max_depth=6, n_estimators=30..............
# [CV 5/5; 13/50] END criterion=gini, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.993) total time=   0.2s
# [CV 1/5; 14/50] START criterion=gini, max_depth=6, n_estimators=40..............
# [CV 1/5; 14/50] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.951) total time=   0.5s
# [CV 2/5; 14/50] START criterion=gini, max_depth=6, n_estimators=40..............
# [CV 2/5; 14/50] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.959) total time=   0.6s
# [CV 3/5; 14/50] START criterion=gini, max_depth=6, n_estimators=40..............
# [CV 3/5; 14/50] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.979) total time=   0.4s
# [CV 4/5; 14/50] START criterion=gini, max_depth=6, n_estimators=40..............
# [CV 4/5; 14/50] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.959) total time=   0.5s
# [CV 5/5; 14/50] START criterion=gini, max_depth=6, n_estimators=40..............
# [CV 5/5; 14/50] END criterion=gini, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.986) total time=   0.5s
# [CV 1/5; 15/50] START criterion=gini, max_depth=6, n_estimators=50..............
# [CV 1/5; 15/50] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.997, test=0.944) total time=   0.6s
# [CV 2/5; 15/50] START criterion=gini, max_depth=6, n_estimators=50..............
# [CV 2/5; 15/50] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.997, test=0.959) total time=   0.8s
# [CV 3/5; 15/50] START criterion=gini, max_depth=6, n_estimators=50..............
# [CV 3/5; 15/50] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.997, test=0.979) total time=   0.7s
# [CV 4/5; 15/50] START criterion=gini, max_depth=6, n_estimators=50..............
# [CV 4/5; 15/50] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.997, test=0.972) total time=   0.7s
# [CV 5/5; 15/50] START criterion=gini, max_depth=6, n_estimators=50..............
# [CV 5/5; 15/50] END criterion=gini, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.986) total time=   0.7s
# [CV 1/5; 16/50] START criterion=gini, max_depth=8, n_estimators=10..............
# [CV 1/5; 16/50] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.950) total time=   0.1s
# [CV 2/5; 16/50] START criterion=gini, max_depth=8, n_estimators=10..............
# [CV 2/5; 16/50] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.996, test=0.959) total time=   0.1s
# [CV 3/5; 16/50] START criterion=gini, max_depth=8, n_estimators=10..............
# [CV 3/5; 16/50] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.995, test=0.965) total time=   0.0s
# [CV 4/5; 16/50] START criterion=gini, max_depth=8, n_estimators=10..............
# [CV 4/5; 16/50] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.972) total time=   0.0s
# [CV 5/5; 16/50] START criterion=gini, max_depth=8, n_estimators=10..............
# [CV 5/5; 16/50] END criterion=gini, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.979) total time=   0.1s
# [CV 1/5; 17/50] START criterion=gini, max_depth=8, n_estimators=20..............
# [CV 1/5; 17/50] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.943) total time=   0.2s
# [CV 2/5; 17/50] START criterion=gini, max_depth=8, n_estimators=20..............
# [CV 2/5; 17/50] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.959) total time=   0.2s
# [CV 3/5; 17/50] START criterion=gini, max_depth=8, n_estimators=20..............
# [CV 3/5; 17/50] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.986) total time=   0.1s
# [CV 4/5; 17/50] START criterion=gini, max_depth=8, n_estimators=20..............
# [CV 4/5; 17/50] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.3s
# [CV 5/5; 17/50] START criterion=gini, max_depth=8, n_estimators=20..............
# [CV 5/5; 17/50] END criterion=gini, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 1/5; 18/50] START criterion=gini, max_depth=8, n_estimators=30..............
# [CV 1/5; 18/50] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.943) total time=   0.4s
# [CV 2/5; 18/50] START criterion=gini, max_depth=8, n_estimators=30..............
# [CV 2/5; 18/50] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.959) total time=   0.4s
# [CV 3/5; 18/50] START criterion=gini, max_depth=8, n_estimators=30..............
# [CV 3/5; 18/50] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 4/5; 18/50] START criterion=gini, max_depth=8, n_estimators=30..............
# [CV 4/5; 18/50] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.952) total time=   0.5s
# [CV 5/5; 18/50] START criterion=gini, max_depth=8, n_estimators=30..............
# [CV 5/5; 18/50] END criterion=gini, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 1/5; 19/50] START criterion=gini, max_depth=8, n_estimators=40..............
# [CV 1/5; 19/50] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=0.998, test=0.944) total time=   0.6s
# [CV 2/5; 19/50] START criterion=gini, max_depth=8, n_estimators=40..............
# [CV 2/5; 19/50] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=0.998, test=0.959) total time=   0.5s
# [CV 3/5; 19/50] START criterion=gini, max_depth=8, n_estimators=40..............
# [CV 3/5; 19/50] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 4/5; 19/50] START criterion=gini, max_depth=8, n_estimators=40..............
# [CV 4/5; 19/50] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.6s
# [CV 5/5; 19/50] START criterion=gini, max_depth=8, n_estimators=40..............
# [CV 5/5; 19/50] END criterion=gini, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.986) total time=   0.6s
# [CV 1/5; 20/50] START criterion=gini, max_depth=8, n_estimators=50..............
# [CV 1/5; 20/50] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=0.998, test=0.958) total time=   0.7s
# [CV 2/5; 20/50] START criterion=gini, max_depth=8, n_estimators=50..............
# [CV 2/5; 20/50] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.7s
# [CV 3/5; 20/50] START criterion=gini, max_depth=8, n_estimators=50..............
# [CV 3/5; 20/50] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 4/5; 20/50] START criterion=gini, max_depth=8, n_estimators=50..............
# [CV 4/5; 20/50] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.966) total time=   0.7s
# [CV 5/5; 20/50] START criterion=gini, max_depth=8, n_estimators=50..............
# [CV 5/5; 20/50] END criterion=gini, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 1/5; 21/50] START criterion=gini, max_depth=10, n_estimators=10.............
# [CV 1/5; 21/50] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.936) total time=   0.1s
# [CV 2/5; 21/50] START criterion=gini, max_depth=10, n_estimators=10.............
# [CV 2/5; 21/50] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=0.996, test=0.959) total time=   0.1s
# [CV 3/5; 21/50] START criterion=gini, max_depth=10, n_estimators=10.............
# [CV 3/5; 21/50] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=0.997, test=0.965) total time=   0.0s
# [CV 4/5; 21/50] START criterion=gini, max_depth=10, n_estimators=10.............
# [CV 4/5; 21/50] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.972) total time=   0.2s
# [CV 5/5; 21/50] START criterion=gini, max_depth=10, n_estimators=10.............
# [CV 5/5; 21/50] END criterion=gini, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.979) total time=   0.1s
# [CV 1/5; 22/50] START criterion=gini, max_depth=10, n_estimators=20.............
# [CV 1/5; 22/50] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=0.998, test=0.943) total time=   0.1s
# [CV 2/5; 22/50] START criterion=gini, max_depth=10, n_estimators=20.............
# [CV 2/5; 22/50] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=0.998, test=0.959) total time=   0.2s
# [CV 3/5; 22/50] START criterion=gini, max_depth=10, n_estimators=20.............
# [CV 3/5; 22/50] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=0.998, test=0.986) total time=   0.2s
# [CV 4/5; 22/50] START criterion=gini, max_depth=10, n_estimators=20.............
# [CV 4/5; 22/50] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 5/5; 22/50] START criterion=gini, max_depth=10, n_estimators=20.............
# [CV 5/5; 22/50] END criterion=gini, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.979) total time=   0.2s
# [CV 1/5; 23/50] START criterion=gini, max_depth=10, n_estimators=30.............
# [CV 1/5; 23/50] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=0.998, test=0.936) total time=   0.4s
# [CV 2/5; 23/50] START criterion=gini, max_depth=10, n_estimators=30.............
# [CV 2/5; 23/50] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=0.998, test=0.952) total time=   0.4s
# [CV 3/5; 23/50] START criterion=gini, max_depth=10, n_estimators=30.............
# [CV 3/5; 23/50] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.986) total time=   0.5s
# [CV 4/5; 23/50] START criterion=gini, max_depth=10, n_estimators=30.............
# [CV 4/5; 23/50] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.952) total time=   0.4s
# [CV 5/5; 23/50] START criterion=gini, max_depth=10, n_estimators=30.............
# [CV 5/5; 23/50] END criterion=gini, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 1/5; 24/50] START criterion=gini, max_depth=10, n_estimators=40.............
# [CV 1/5; 24/50] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=0.998, test=0.944) total time=   0.5s
# [CV 2/5; 24/50] START criterion=gini, max_depth=10, n_estimators=40.............
# [CV 2/5; 24/50] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.959) total time=   0.7s
# [CV 3/5; 24/50] START criterion=gini, max_depth=10, n_estimators=40.............
# [CV 3/5; 24/50] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.986) total time=   0.5s
# [CV 4/5; 24/50] START criterion=gini, max_depth=10, n_estimators=40.............
# [CV 4/5; 24/50] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.973) total time=   0.6s
# [CV 5/5; 24/50] START criterion=gini, max_depth=10, n_estimators=40.............
# [CV 5/5; 24/50] END criterion=gini, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.986) total time=   0.5s
# [CV 1/5; 25/50] START criterion=gini, max_depth=10, n_estimators=50.............
# [CV 1/5; 25/50] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=0.998, test=0.951) total time=   0.7s
# [CV 2/5; 25/50] START criterion=gini, max_depth=10, n_estimators=50.............
# [CV 2/5; 25/50] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.6s
# [CV 3/5; 25/50] START criterion=gini, max_depth=10, n_estimators=50.............
# [CV 3/5; 25/50] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.8s
# [CV 4/5; 25/50] START criterion=gini, max_depth=10, n_estimators=50.............
# [CV 4/5; 25/50] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.966) total time=   0.7s
# [CV 5/5; 25/50] START criterion=gini, max_depth=10, n_estimators=50.............
# [CV 5/5; 25/50] END criterion=gini, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.7s
# [CV 1/5; 26/50] START criterion=entropy, max_depth=2, n_estimators=10...........
# [CV 1/5; 26/50] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.962, test=0.913) total time=   0.0s
# [CV 2/5; 26/50] START criterion=entropy, max_depth=2, n_estimators=10...........
# [CV 2/5; 26/50] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.972, test=0.939) total time=   0.0s
# [CV 3/5; 26/50] START criterion=entropy, max_depth=2, n_estimators=10...........
# [CV 3/5; 26/50] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.955, test=0.972) total time=   0.0s
# [CV 4/5; 26/50] START criterion=entropy, max_depth=2, n_estimators=10...........
# [CV 4/5; 26/50] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.963, test=0.966) total time=   0.0s
# [CV 5/5; 26/50] START criterion=entropy, max_depth=2, n_estimators=10...........
# [CV 5/5; 26/50] END criterion=entropy, max_depth=2, n_estimators=10;, score=(train=0.965, test=0.971) total time=   0.0s
# [CV 1/5; 27/50] START criterion=entropy, max_depth=2, n_estimators=20...........
# [CV 1/5; 27/50] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.964, test=0.938) total time=   0.2s
# [CV 2/5; 27/50] START criterion=entropy, max_depth=2, n_estimators=20...........
# [CV 2/5; 27/50] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.972, test=0.952) total time=   0.1s
# [CV 3/5; 27/50] START criterion=entropy, max_depth=2, n_estimators=20...........
# [CV 3/5; 27/50] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.963, test=0.972) total time=   0.1s
# [CV 4/5; 27/50] START criterion=entropy, max_depth=2, n_estimators=20...........
# [CV 4/5; 27/50] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.968, test=0.966) total time=   0.2s
# [CV 5/5; 27/50] START criterion=entropy, max_depth=2, n_estimators=20...........
# [CV 5/5; 27/50] END criterion=entropy, max_depth=2, n_estimators=20;, score=(train=0.972, test=0.971) total time=   0.2s
# [CV 1/5; 28/50] START criterion=entropy, max_depth=2, n_estimators=30...........
# [CV 1/5; 28/50] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.971, test=0.945) total time=   0.2s
# [CV 2/5; 28/50] START criterion=entropy, max_depth=2, n_estimators=30...........
# [CV 2/5; 28/50] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.974, test=0.939) total time=   0.4s
# [CV 3/5; 28/50] START criterion=entropy, max_depth=2, n_estimators=30...........
# [CV 3/5; 28/50] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.966, test=0.979) total time=   0.2s
# [CV 4/5; 28/50] START criterion=entropy, max_depth=2, n_estimators=30...........
# [CV 4/5; 28/50] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.976, test=0.966) total time=   0.2s
# [CV 5/5; 28/50] START criterion=entropy, max_depth=2, n_estimators=30...........
# [CV 5/5; 28/50] END criterion=entropy, max_depth=2, n_estimators=30;, score=(train=0.969, test=0.971) total time=   0.3s
# [CV 1/5; 29/50] START criterion=entropy, max_depth=2, n_estimators=40...........
# [CV 1/5; 29/50] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.969, test=0.925) total time=   0.4s
# [CV 2/5; 29/50] START criterion=entropy, max_depth=2, n_estimators=40...........
# [CV 2/5; 29/50] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.972, test=0.952) total time=   0.5s
# [CV 3/5; 29/50] START criterion=entropy, max_depth=2, n_estimators=40...........
# [CV 3/5; 29/50] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.964, test=0.979) total time=   0.5s
# [CV 4/5; 29/50] START criterion=entropy, max_depth=2, n_estimators=40...........
# [CV 4/5; 29/50] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.970, test=0.966) total time=   0.4s
# [CV 5/5; 29/50] START criterion=entropy, max_depth=2, n_estimators=40...........
# [CV 5/5; 29/50] END criterion=entropy, max_depth=2, n_estimators=40;, score=(train=0.967, test=0.971) total time=   0.4s
# [CV 1/5; 30/50] START criterion=entropy, max_depth=2, n_estimators=50...........
# [CV 1/5; 30/50] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.966, test=0.920) total time=   0.4s
# [CV 2/5; 30/50] START criterion=entropy, max_depth=2, n_estimators=50...........
# [CV 2/5; 30/50] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.972, test=0.946) total time=   0.5s
# [CV 3/5; 30/50] START criterion=entropy, max_depth=2, n_estimators=50...........
# [CV 3/5; 30/50] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.962, test=0.966) total time=   0.5s
# [CV 4/5; 30/50] START criterion=entropy, max_depth=2, n_estimators=50...........
# [CV 4/5; 30/50] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.974, test=0.966) total time=   0.8s
# [CV 5/5; 30/50] START criterion=entropy, max_depth=2, n_estimators=50...........
# [CV 5/5; 30/50] END criterion=entropy, max_depth=2, n_estimators=50;, score=(train=0.969, test=0.971) total time=   0.5s
# [CV 1/5; 31/50] START criterion=entropy, max_depth=4, n_estimators=10...........
# [CV 1/5; 31/50] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.991, test=0.952) total time=   0.1s
# [CV 2/5; 31/50] START criterion=entropy, max_depth=4, n_estimators=10...........
# [CV 2/5; 31/50] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.993, test=0.966) total time=   0.1s
# [CV 3/5; 31/50] START criterion=entropy, max_depth=4, n_estimators=10...........
# [CV 3/5; 31/50] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.986, test=0.979) total time=   0.1s
# [CV 4/5; 31/50] START criterion=entropy, max_depth=4, n_estimators=10...........
# [CV 4/5; 31/50] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.991, test=0.972) total time=   0.1s
# [CV 5/5; 31/50] START criterion=entropy, max_depth=4, n_estimators=10...........
# [CV 5/5; 31/50] END criterion=entropy, max_depth=4, n_estimators=10;, score=(train=0.990, test=0.986) total time=   0.1s
# [CV 1/5; 32/50] START criterion=entropy, max_depth=4, n_estimators=20...........
# [CV 1/5; 32/50] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.993, test=0.950) total time=   0.2s
# [CV 2/5; 32/50] START criterion=entropy, max_depth=4, n_estimators=20...........
# [CV 2/5; 32/50] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.995, test=0.959) total time=   0.2s
# [CV 3/5; 32/50] START criterion=entropy, max_depth=4, n_estimators=20...........
# [CV 3/5; 32/50] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.988, test=0.993) total time=   0.1s
# [CV 4/5; 32/50] START criterion=entropy, max_depth=4, n_estimators=20...........
# [CV 4/5; 32/50] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.993, test=0.986) total time=   0.3s
# [CV 5/5; 32/50] START criterion=entropy, max_depth=4, n_estimators=20...........
# [CV 5/5; 32/50] END criterion=entropy, max_depth=4, n_estimators=20;, score=(train=0.990, test=0.986) total time=   0.3s
# [CV 1/5; 33/50] START criterion=entropy, max_depth=4, n_estimators=30...........
# [CV 1/5; 33/50] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.993, test=0.958) total time=   0.3s
# [CV 2/5; 33/50] START criterion=entropy, max_depth=4, n_estimators=30...........
# [CV 2/5; 33/50] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.993, test=0.959) total time=   0.3s
# [CV 3/5; 33/50] START criterion=entropy, max_depth=4, n_estimators=30...........
# [CV 3/5; 33/50] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.979) total time=   0.4s
# [CV 4/5; 33/50] START criterion=entropy, max_depth=4, n_estimators=30...........
# [CV 4/5; 33/50] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.995, test=0.973) total time=   0.4s
# [CV 5/5; 33/50] START criterion=entropy, max_depth=4, n_estimators=30...........
# [CV 5/5; 33/50] END criterion=entropy, max_depth=4, n_estimators=30;, score=(train=0.991, test=0.986) total time=   0.4s
# [CV 1/5; 34/50] START criterion=entropy, max_depth=4, n_estimators=40...........
# [CV 1/5; 34/50] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.993, test=0.972) total time=   0.6s
# [CV 2/5; 34/50] START criterion=entropy, max_depth=4, n_estimators=40...........
# [CV 2/5; 34/50] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.993, test=0.959) total time=   0.4s
# [CV 3/5; 34/50] START criterion=entropy, max_depth=4, n_estimators=40...........
# [CV 3/5; 34/50] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.979) total time=   0.6s
# [CV 4/5; 34/50] START criterion=entropy, max_depth=4, n_estimators=40...........
# [CV 4/5; 34/50] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.995, test=0.980) total time=   0.5s
# [CV 5/5; 34/50] START criterion=entropy, max_depth=4, n_estimators=40...........
# [CV 5/5; 34/50] END criterion=entropy, max_depth=4, n_estimators=40;, score=(train=0.991, test=0.979) total time=   0.4s
# [CV 1/5; 35/50] START criterion=entropy, max_depth=4, n_estimators=50...........
# [CV 1/5; 35/50] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.993, test=0.958) total time=   0.6s
# [CV 2/5; 35/50] START criterion=entropy, max_depth=4, n_estimators=50...........
# [CV 2/5; 35/50] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.995, test=0.952) total time=   0.6s
# [CV 3/5; 35/50] START criterion=entropy, max_depth=4, n_estimators=50...........
# [CV 3/5; 35/50] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.986) total time=   0.6s
# [CV 4/5; 35/50] START criterion=entropy, max_depth=4, n_estimators=50...........
# [CV 4/5; 35/50] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.995, test=0.980) total time=   0.6s
# [CV 5/5; 35/50] START criterion=entropy, max_depth=4, n_estimators=50...........
# [CV 5/5; 35/50] END criterion=entropy, max_depth=4, n_estimators=50;, score=(train=0.991, test=0.979) total time=   0.6s
# [CV 1/5; 36/50] START criterion=entropy, max_depth=6, n_estimators=10...........
# [CV 1/5; 36/50] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.998, test=0.958) total time=   0.0s
# [CV 2/5; 36/50] START criterion=entropy, max_depth=6, n_estimators=10...........
# [CV 2/5; 36/50] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=1.000, test=0.959) total time=   0.0s
# [CV 3/5; 36/50] START criterion=entropy, max_depth=6, n_estimators=10...........
# [CV 3/5; 36/50] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.979) total time=   0.1s
# [CV 4/5; 36/50] START criterion=entropy, max_depth=6, n_estimators=10...........
# [CV 4/5; 36/50] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.973) total time=   0.0s
# [CV 5/5; 36/50] START criterion=entropy, max_depth=6, n_estimators=10...........
# [CV 5/5; 36/50] END criterion=entropy, max_depth=6, n_estimators=10;, score=(train=0.997, test=0.986) total time=   0.1s
# [CV 1/5; 37/50] START criterion=entropy, max_depth=6, n_estimators=20...........
# [CV 1/5; 37/50] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.950) total time=   0.2s
# [CV 2/5; 37/50] START criterion=entropy, max_depth=6, n_estimators=20...........
# [CV 2/5; 37/50] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.997, test=0.959) total time=   0.4s
# [CV 3/5; 37/50] START criterion=entropy, max_depth=6, n_estimators=20...........
# [CV 3/5; 37/50] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.993) total time=   0.3s
# [CV 4/5; 37/50] START criterion=entropy, max_depth=6, n_estimators=20...........
# [CV 4/5; 37/50] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.966) total time=   0.1s
# [CV 5/5; 37/50] START criterion=entropy, max_depth=6, n_estimators=20...........
# [CV 5/5; 37/50] END criterion=entropy, max_depth=6, n_estimators=20;, score=(train=0.998, test=0.979) total time=   0.3s
# [CV 1/5; 38/50] START criterion=entropy, max_depth=6, n_estimators=30...........
# [CV 1/5; 38/50] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.950) total time=   0.4s
# [CV 2/5; 38/50] START criterion=entropy, max_depth=6, n_estimators=30...........
# [CV 2/5; 38/50] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.966) total time=   0.4s
# [CV 3/5; 38/50] START criterion=entropy, max_depth=6, n_estimators=30...........
# [CV 3/5; 38/50] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.993) total time=   0.3s
# [CV 4/5; 38/50] START criterion=entropy, max_depth=6, n_estimators=30...........
# [CV 4/5; 38/50] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/5; 38/50] START criterion=entropy, max_depth=6, n_estimators=30...........
# [CV 5/5; 38/50] END criterion=entropy, max_depth=6, n_estimators=30;, score=(train=0.998, test=0.986) total time=   0.3s
# [CV 1/5; 39/50] START criterion=entropy, max_depth=6, n_estimators=40...........
# [CV 1/5; 39/50] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.958) total time=   0.5s
# [CV 2/5; 39/50] START criterion=entropy, max_depth=6, n_estimators=40...........
# [CV 2/5; 39/50] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.998, test=0.959) total time=   0.5s
# [CV 3/5; 39/50] START criterion=entropy, max_depth=6, n_estimators=40...........
# [CV 3/5; 39/50] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.993) total time=   0.5s
# [CV 4/5; 39/50] START criterion=entropy, max_depth=6, n_estimators=40...........
# [CV 4/5; 39/50] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=1.000, test=0.980) total time=   0.6s
# [CV 5/5; 39/50] START criterion=entropy, max_depth=6, n_estimators=40...........
# [CV 5/5; 39/50] END criterion=entropy, max_depth=6, n_estimators=40;, score=(train=0.997, test=0.979) total time=   0.6s
# [CV 1/5; 40/50] START criterion=entropy, max_depth=6, n_estimators=50...........
# [CV 1/5; 40/50] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.965) total time=   0.6s
# [CV 2/5; 40/50] START criterion=entropy, max_depth=6, n_estimators=50...........
# [CV 2/5; 40/50] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.952) total time=   0.6s
# [CV 3/5; 40/50] START criterion=entropy, max_depth=6, n_estimators=50...........
# [CV 3/5; 40/50] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=0.997, test=0.993) total time=   0.6s
# [CV 4/5; 40/50] START criterion=entropy, max_depth=6, n_estimators=50...........
# [CV 4/5; 40/50] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=1.000, test=0.980) total time=   0.5s
# [CV 5/5; 40/50] START criterion=entropy, max_depth=6, n_estimators=50...........
# [CV 5/5; 40/50] END criterion=entropy, max_depth=6, n_estimators=50;, score=(train=0.998, test=0.979) total time=   0.8s
# [CV 1/5; 41/50] START criterion=entropy, max_depth=8, n_estimators=10...........
# [CV 1/5; 41/50] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=0.997, test=0.958) total time=   0.0s
# [CV 2/5; 41/50] START criterion=entropy, max_depth=8, n_estimators=10...........
# [CV 2/5; 41/50] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 3/5; 41/50] START criterion=entropy, max_depth=8, n_estimators=10...........
# [CV 3/5; 41/50] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.986) total time=   0.0s
# [CV 4/5; 41/50] START criterion=entropy, max_depth=8, n_estimators=10...........
# [CV 4/5; 41/50] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=0.997, test=0.959) total time=   0.1s
# [CV 5/5; 41/50] START criterion=entropy, max_depth=8, n_estimators=10...........
# [CV 5/5; 41/50] END criterion=entropy, max_depth=8, n_estimators=10;, score=(train=0.998, test=0.978) total time=   0.1s
# [CV 1/5; 42/50] START criterion=entropy, max_depth=8, n_estimators=20...........
# [CV 1/5; 42/50] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.958) total time=   0.2s
# [CV 2/5; 42/50] START criterion=entropy, max_depth=8, n_estimators=20...........
# [CV 2/5; 42/50] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=0.998, test=0.966) total time=   0.2s
# [CV 3/5; 42/50] START criterion=entropy, max_depth=8, n_estimators=20...........
# [CV 3/5; 42/50] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.993) total time=   0.3s
# [CV 4/5; 42/50] START criterion=entropy, max_depth=8, n_estimators=20...........
# [CV 4/5; 42/50] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.2s
# [CV 5/5; 42/50] START criterion=entropy, max_depth=8, n_estimators=20...........
# [CV 5/5; 42/50] END criterion=entropy, max_depth=8, n_estimators=20;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 1/5; 43/50] START criterion=entropy, max_depth=8, n_estimators=30...........
# [CV 1/5; 43/50] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.958) total time=   0.5s
# [CV 2/5; 43/50] START criterion=entropy, max_depth=8, n_estimators=30...........
# [CV 2/5; 43/50] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=0.998, test=0.966) total time=   0.4s
# [CV 3/5; 43/50] START criterion=entropy, max_depth=8, n_estimators=30...........
# [CV 3/5; 43/50] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.993) total time=   0.4s
# [CV 4/5; 43/50] START criterion=entropy, max_depth=8, n_estimators=30...........
# [CV 4/5; 43/50] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.4s
# [CV 5/5; 43/50] START criterion=entropy, max_depth=8, n_estimators=30...........
# [CV 5/5; 43/50] END criterion=entropy, max_depth=8, n_estimators=30;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 1/5; 44/50] START criterion=entropy, max_depth=8, n_estimators=40...........
# [CV 1/5; 44/50] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=0.998, test=0.958) total time=   0.6s
# [CV 2/5; 44/50] START criterion=entropy, max_depth=8, n_estimators=40...........
# [CV 2/5; 44/50] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.6s
# [CV 3/5; 44/50] START criterion=entropy, max_depth=8, n_estimators=40...........
# [CV 3/5; 44/50] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.993) total time=   0.5s
# [CV 4/5; 44/50] START criterion=entropy, max_depth=8, n_estimators=40...........
# [CV 4/5; 44/50] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.973) total time=   0.6s
# [CV 5/5; 44/50] START criterion=entropy, max_depth=8, n_estimators=40...........
# [CV 5/5; 44/50] END criterion=entropy, max_depth=8, n_estimators=40;, score=(train=1.000, test=0.979) total time=   0.5s
# [CV 1/5; 45/50] START criterion=entropy, max_depth=8, n_estimators=50...........
# [CV 1/5; 45/50] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=0.998, test=0.965) total time=   0.6s
# [CV 2/5; 45/50] START criterion=entropy, max_depth=8, n_estimators=50...........
# [CV 2/5; 45/50] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.8s
# [CV 3/5; 45/50] START criterion=entropy, max_depth=8, n_estimators=50...........
# [CV 3/5; 45/50] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.993) total time=   0.6s
# [CV 4/5; 45/50] START criterion=entropy, max_depth=8, n_estimators=50...........
# [CV 4/5; 45/50] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.980) total time=   0.7s
# [CV 5/5; 45/50] START criterion=entropy, max_depth=8, n_estimators=50...........
# [CV 5/5; 45/50] END criterion=entropy, max_depth=8, n_estimators=50;, score=(train=1.000, test=0.979) total time=   0.6s
# [CV 1/5; 46/50] START criterion=entropy, max_depth=10, n_estimators=10..........
# [CV 1/5; 46/50] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.958) total time=   0.0s
# [CV 2/5; 46/50] START criterion=entropy, max_depth=10, n_estimators=10..........
# [CV 2/5; 46/50] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=1.000, test=0.952) total time=   0.1s
# [CV 3/5; 46/50] START criterion=entropy, max_depth=10, n_estimators=10..........
# [CV 3/5; 46/50] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.986) total time=   0.1s
# [CV 4/5; 46/50] START criterion=entropy, max_depth=10, n_estimators=10..........
# [CV 4/5; 46/50] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=0.997, test=0.959) total time=   0.1s
# [CV 5/5; 46/50] START criterion=entropy, max_depth=10, n_estimators=10..........
# [CV 5/5; 46/50] END criterion=entropy, max_depth=10, n_estimators=10;, score=(train=0.998, test=0.978) total time=   0.1s
# [CV 1/5; 47/50] START criterion=entropy, max_depth=10, n_estimators=20..........
# [CV 1/5; 47/50] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=0.998, test=0.950) total time=   0.2s
# [CV 2/5; 47/50] START criterion=entropy, max_depth=10, n_estimators=20..........
# [CV 2/5; 47/50] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=0.998, test=0.966) total time=   0.2s
# [CV 3/5; 47/50] START criterion=entropy, max_depth=10, n_estimators=20..........
# [CV 3/5; 47/50] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.993) total time=   0.2s
# [CV 4/5; 47/50] START criterion=entropy, max_depth=10, n_estimators=20..........
# [CV 4/5; 47/50] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.959) total time=   0.1s
# [CV 5/5; 47/50] START criterion=entropy, max_depth=10, n_estimators=20..........
# [CV 5/5; 47/50] END criterion=entropy, max_depth=10, n_estimators=20;, score=(train=1.000, test=0.986) total time=   0.3s
# [CV 1/5; 48/50] START criterion=entropy, max_depth=10, n_estimators=30..........
# [CV 1/5; 48/50] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=0.998, test=0.958) total time=   0.3s
# [CV 2/5; 48/50] START criterion=entropy, max_depth=10, n_estimators=30..........
# [CV 2/5; 48/50] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=0.998, test=0.966) total time=   0.4s
# [CV 3/5; 48/50] START criterion=entropy, max_depth=10, n_estimators=30..........
# [CV 3/5; 48/50] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.993) total time=   0.5s
# [CV 4/5; 48/50] START criterion=entropy, max_depth=10, n_estimators=30..........
# [CV 4/5; 48/50] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.973) total time=   0.3s
# [CV 5/5; 48/50] START criterion=entropy, max_depth=10, n_estimators=30..........
# [CV 5/5; 48/50] END criterion=entropy, max_depth=10, n_estimators=30;, score=(train=1.000, test=0.986) total time=   0.4s
# [CV 1/5; 49/50] START criterion=entropy, max_depth=10, n_estimators=40..........
# [CV 1/5; 49/50] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=0.998, test=0.958) total time=   0.6s
# [CV 2/5; 49/50] START criterion=entropy, max_depth=10, n_estimators=40..........
# [CV 2/5; 49/50] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.966) total time=   0.6s
# [CV 3/5; 49/50] START criterion=entropy, max_depth=10, n_estimators=40..........
# [CV 3/5; 49/50] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.993) total time=   0.4s
# [CV 4/5; 49/50] START criterion=entropy, max_depth=10, n_estimators=40..........
# [CV 4/5; 49/50] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.973) total time=   0.5s
# [CV 5/5; 49/50] START criterion=entropy, max_depth=10, n_estimators=40..........
# [CV 5/5; 49/50] END criterion=entropy, max_depth=10, n_estimators=40;, score=(train=1.000, test=0.979) total time=   0.5s
# [CV 1/5; 50/50] START criterion=entropy, max_depth=10, n_estimators=50..........
# [CV 1/5; 50/50] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=0.998, test=0.965) total time=   0.7s
# [CV 2/5; 50/50] START criterion=entropy, max_depth=10, n_estimators=50..........
# [CV 2/5; 50/50] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.959) total time=   0.6s
# [CV 3/5; 50/50] START criterion=entropy, max_depth=10, n_estimators=50..........
# [CV 3/5; 50/50] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.993) total time=   0.7s
# [CV 4/5; 50/50] START criterion=entropy, max_depth=10, n_estimators=50..........
# [CV 4/5; 50/50] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.980) total time=   0.7s
# [CV 5/5; 50/50] START criterion=entropy, max_depth=10, n_estimators=50..........
# [CV 5/5; 50/50] END criterion=entropy, max_depth=10, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.7s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=1, random_state=2),
#              n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'n_estimators': [10, 20, 30, 40, 50]},
#              return_train_score=True, scoring='f1', verbose=10)
